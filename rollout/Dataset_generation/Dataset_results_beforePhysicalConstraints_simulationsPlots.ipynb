# %%
import sklearn
import numpy as np
import os, sys

# To plot pretty figures
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

import pandas as pd

# %%
folders = [
    'dataset_MonteCarlo_500.000/',
    'dataset_MonteCarlo_ranges_500.000/',
    'dataset_MonteCarlo_ranges_zeros_500.000/',
    'dataset_MonteCarlo_zeros_500.000/',
    'dataset_MonteCarlo_cov_500.000/',
]

# %%
list_df=[]
for folder in folders:
    list_df.append(pd.read_csv('../../datasets/'+folder+'results-100.csv'))
df_orig = pd.read_csv('../../datasets/icferst_run_orig/time_series.csv')

# %%
for i in range(len(list_df)):
    list_df[i] = list_df[i][['Time','avg(Time)','avg(Species_Ca+2)','avg(Species_Cl-)','avg(Species_K+)','avg(Species_NO3-)','avg(Species_Na+)']]
df_orig = df_orig[['Time','avg(Time)','avg(Species_Ca+2)','avg(Species_Cl-)','avg(Species_K+)','avg(Species_NO3-)','avg(Species_Na+)']]

# %%
df_orig
# Out:
#      Time  avg(Time)  avg(Species_Ca+2)  avg(Species_Cl-)  avg(Species_K+)  \
# 0       0          0             0.0000      0.000000e+00     2.000000e-04
# 1       1        720             0.0000      0.000000e+00     1.994000e-04
# 2       2       1440             0.0000      0.000000e+00     1.994000e-04
# 3       3       2160             0.0000      0.000000e+00     1.994000e-04
# 4       4       2880             0.0000      1.267540e-23     1.994000e-04
# ..    ...        ...                ...               ...              ...
# 117   117      84240             0.0006      1.199990e-03     1.542880e-08
# 118   118      84960             0.0006      1.199990e-03     1.227440e-08
# 119   119      85680             0.0006      1.199990e-03     9.763230e-09
# 120   120      86400             0.0006      1.199990e-03     7.771020e-09
# 121   121      86400             0.0006      1.199990e-03     7.771020e-09
#
#      avg(Species_NO3-)  avg(Species_Na+)
# 0             0.001200          0.001000
# 1             0.001196          0.000997
# 2             0.001196          0.000997
# 3             0.001196          0.000997
# 4             0.001196          0.000997
# ..                 ...               ...
# 117           0.000000          0.000000
# 118           0.000000          0.000000
# 119           0.000000          0.000000
# 120           0.000000          0.000000
# 121           0.000000          0.000000
#
# [122 rows x 7 columns]

# %%
fig, ax = plt.subplots(1,1,figsize=(8,5))
df_orig[['avg(Species_Ca+2)','avg(Species_K+)','avg(Species_Na+)']].plot(linestyle='none', marker='.',markerfacecolor='none', ax=ax)
# Out:
# <AxesSubplot:>

# %%
fig, axs = plt.subplots(len(list_df),1,figsize=(8,30),)
for i in range(len(list_df)):
    list_df[i][['avg(Species_Ca+2)','avg(Species_K+)','avg(Species_Na+)']].plot(ax=axs[i],title=folders[i])
    axs[i].set_prop_cycle(None)
    df_orig[['avg(Species_Ca+2)','avg(Species_K+)','avg(Species_Na+)']].plot(linestyle='none', marker='.',markerfacecolor='none',ax=axs[i],title=folders[i],legend=None)

# %%
fig, axs = plt.subplots(1,1,figsize=(8,5),)
for i in range(0,1):
    #list_df[i][['avg(Species_Ca+2)','avg(Species_K+)','avg(Species_Na+)']].plot(ax=axs)
    #axs.set_prop_cycle(None)
    df_orig[['avg(Species_Ca+2)','avg(Species_K+)','avg(Species_Na+)']].plot(linestyle='none', label=['Ca+2','K+','Na+'],marker='.',markerfacecolor='none',markersize=14,ax=axs,legend=None)
    plt.grid()
axs.legend(['Ca+2','K+','Na+'])   
axs.set_xlabel('Time steps')
axs.set_ylabel('Concentration (mol/kgw)')
plt.savefig('sim_preeqc.eps')
# Out:
# Text(0, 0.5, 'Concentration (mol/kgw)')

# %%
fig, axs = plt.subplots(1,1,figsize=(8,5),)
for i in range(0,1):
    list_df[i][['avg(Species_Ca+2)','avg(Species_K+)','avg(Species_Na+)']].plot(ax=axs)
    axs.set_prop_cycle(None)
    df_orig[['avg(Species_Ca+2)','avg(Species_K+)','avg(Species_Na+)']].plot(linestyle='none', label=['Ca+2','K+','Na+'],marker='.',markerfacecolor='none',markersize=14,ax=axs,legend=None)
    plt.grid()
axs.legend(['Ca+2 (ML)','K+ (ML)','Na+ (ML)','Ca+2','K+','Na+'])   
axs.set_xlabel('Time steps')
axs.set_ylabel('Concentration (mol/kgw)')
plt.savefig('sim_mc100.eps')
# Out:
# Text(0, 0.5, 'Concentration (mol/kgw)')

# %%
fig, axs = plt.subplots(1,1,figsize=(8,5),)
for i in range(3,4):
    list_df[i][['avg(Species_Ca+2)','avg(Species_K+)','avg(Species_Na+)']].plot(ax=axs)
    axs.set_prop_cycle(None)
    df_orig[['avg(Species_Ca+2)','avg(Species_K+)','avg(Species_Na+)']].plot(linestyle='none', label=['Ca+2','K+','Na+'],marker='.',markerfacecolor='none',markersize=14,ax=axs,legend=None)
    plt.grid()
axs.legend(['Ca+2 (ML)','K+ (ML)','Na+ (ML)','Ca+2','K+','Na+'])   
axs.set_xlabel('Time steps')
axs.set_ylabel('Concentration (mol/kgw)')
plt.savefig('sim_zeros100.eps')
# Out:
# Text(0, 0.5, 'Concentration (mol/kgw)')
