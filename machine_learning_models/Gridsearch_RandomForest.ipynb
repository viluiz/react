# %%
# %reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %%
# Python ≥3.5 is required
import sys
assert sys.version_info >= (3, 5)

# Scikit-Learn ≥1.0.2 is required
import sklearn
assert sklearn.__version__ >= "1.0.2"

# Common imports
import numpy as np
import os
import pandas as pd
import time

# To plot pretty figures
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rcParams.update({'font.size': 20})
mpl.rc('xtick', labelsize=18) 
mpl.rc('ytick', labelsize=18) 
mpl.rc('axes', labelsize=22)

# %% [markdown]
# # Load and process data

# %%
# read data from csv file
trainset = pd.read_csv('../datasets/dataset_MonteCarlo_100.000/trainset.csv')
testset = pd.read_csv('../datasets/dataset_MonteCarlo_100.000/testset.csv')
print(trainset.shape)
print(testset.shape)
# Out:
# (80000, 15)
# (20000, 15)

# %%
trainset
# Out:
#            0_Ca      0_Cl      0_Na       0_K      0_N5      1_Ca      1_Cl  \
# 0      0.341575  1.159034  0.012636  0.451710  0.794808  0.347226  0.116634
# 1      0.638607  0.558054  1.231009  0.243433  1.132821  0.038278  0.185744
# 2      0.787981  0.763241  0.349968  0.738449  1.452716  1.117356  0.110285
# 3      0.466115  0.948450  0.942671  1.051085  1.358636  0.470234  0.252135
# 4      0.452663  0.644895  1.360873  0.991130  0.162887  1.361588  1.475943
# ...         ...       ...       ...       ...       ...       ...       ...
# 79995  0.796601  0.398041  1.132371  0.996845  0.094560  1.074895  1.055513
# 79996  0.942419  1.456538  1.164360  0.775981  0.069458  1.024540  1.025283
# 79997  1.095302  0.438446  1.335379  0.365207  0.273701  0.765942  0.880543
# 79998  0.310626  0.661302  0.192742  1.280823  0.931653  0.199012  0.072267
# 79999  0.615264  0.605845  0.029464  0.670703  0.573957  0.756683  0.786792
#
#            1_Na       1_K      1_N5  out_Ca  out_Cl   out_Na   out_K   out_N5
# 0      0.755911  0.674340  1.359338  0.3233  1.1590  0.02901  0.4719  0.79480
# 1      0.734268  1.464984  1.489907  0.4584  0.5581  1.24700  0.5882  1.13300
# 2      0.393380  0.282715  1.466671  0.8053  0.7632  0.34980  0.7038  1.45300
# 3      0.914662  1.318543  1.076570  0.4558  0.9484  0.94180  1.0730  1.35900
# 4      0.637112  0.397679  1.414160  0.4939  0.6449  1.34300  0.9266  0.16290
# ...         ...       ...       ...     ...     ...      ...     ...      ...
# 79995  0.777877  0.870241  0.361988  0.8083  0.3980  1.12600  0.9802  0.09456
# 79996  0.144121  1.438743  0.241862  0.9305  1.4570  1.15000  0.8141  0.06946
# 79997  1.152310  1.119219  1.104459  1.0670  0.4384  1.33500  0.4223  0.27370
# 79998  0.870017  0.563615  0.006399  0.3275  0.6613  0.21380  1.2260  0.93170
# 79999  0.335492  1.038286  1.078064  0.6031  0.6058  0.03403  0.6905  0.57400
#
# [80000 rows x 15 columns]

# %%
trainset.hist(figsize=(18, 15));
plt.tight_layout()

# %%
# split x and y
X_train = trainset.iloc[:, [0,2,3,5,7,8]].values 
y_train = trainset.iloc[:, [10, 12, 13]].values
X_test = testset.iloc[:, [0,2,3,5,7,8]].values 
y_test = testset.iloc[:, [10, 12, 13]].values

# Name variables
inputs = [list(trainset)[i] for i in [0,2,3,5,7,8]] 
outputs = [list(trainset)[i] for i in [10, 12, 13]] # do not work for list -> list(trainset)[10, 12, 13]

# %%
print('Inputs: ', inputs)
print('Outputs: ', outputs)
print('X_train instances: ', X_train.shape)
print('X_test instances: ', X_test.shape)
print('y_train instances: ', y_train.shape)
print('y_test instances: ', y_test.shape)
# Out:
# Inputs:  ['0_Ca', '0_Na', '0_K', '1_Ca', '1_Na', '1_K']
# Outputs:  ['out_Ca', 'out_Na', 'out_K']
# X_train instances:  (80000, 6)
# X_test instances:  (20000, 6)
# y_train instances:  (80000, 3)
# y_test instances:  (20000, 3)

# %% [markdown]
# ## Normalize data

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import MinMaxScaler

norm_pipeline = Pipeline([
        ('minmax_scaler', MinMaxScaler((-1,1))),
    ])

X_train_norm = norm_pipeline.fit_transform(X_train)
X_test_norm = norm_pipeline.transform(X_test)

# %% [markdown]
# # Fine Tuning

# %% [markdown]
# ## sklearn RF

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV

param_grid = [
    # try combinations of hyperparameters
    {'bootstrap': [True, False], 
     'n_estimators': [50, 75, 100],  
     'max_features': [0.4, 0.6, 0.8, 1.0],
     'max_depth': [10, 20, 30],
     'min_samples_leaf': [1, 2, 4],
     'min_samples_split': [2, 4, 8]
    }]

# train across 3 folds
grid_search = GridSearchCV(RandomForestRegressor(random_state=42),
                           param_grid, 
                           cv=3,
                           scoring='neg_mean_squared_error',
                           return_train_score=True, 
                           verbose = 1,
                           n_jobs= -1)
start = time.time()
grid_search.fit(X_train_norm, y_train)
print("Run time = ", time.time()-start)
# Out:
# Fitting 3 folds for each of 648 candidates, totalling 1944 fits
# Run time =  487.23733711242676

# %%
print(f"best parameters: {grid_search.best_params_}")
print(f"best score:      {-grid_search.best_score_:0.5f} (+/-{grid_search.cv_results_['std_test_score'][grid_search.best_index_]:0.5f})")
# Out:
# best parameters: {'bootstrap': False, 'max_depth': 20, 'max_features': 0.6, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}
# best score:      0.00074 (+/-0.00003)

# %%
results_df = pd.DataFrame(grid_search.cv_results_)
results_df = results_df.sort_values(by=["rank_test_score"])
results_df[["params", "rank_test_score", "mean_train_score", "std_train_score", "mean_test_score", "std_test_score"]]
# Out:
#                                                 params  rank_test_score  \
# 461  {'bootstrap': False, 'max_depth': 20, 'max_fea...                1
# 569  {'bootstrap': False, 'max_depth': 30, 'max_fea...                2
# 460  {'bootstrap': False, 'max_depth': 20, 'max_fea...                3
# 568  {'bootstrap': False, 'max_depth': 30, 'max_fea...                4
# 567  {'bootstrap': False, 'max_depth': 30, 'max_fea...                5
# ..                                                 ...              ...
# 333  {'bootstrap': False, 'max_depth': 10, 'max_fea...              643
# 6    {'bootstrap': True, 'max_depth': 10, 'max_feat...              645
# 330  {'bootstrap': False, 'max_depth': 10, 'max_fea...              646
# 339  {'bootstrap': False, 'max_depth': 10, 'max_fea...              647
# 327  {'bootstrap': False, 'max_depth': 10, 'max_fea...              648
#
#      mean_train_score  std_train_score  mean_test_score  std_test_score
# 461     -5.714799e-08     3.685061e-09        -0.000743        0.000030
# 569     -1.443703e-30     1.100448e-33        -0.000748        0.000027
# 460     -6.735994e-08     3.340627e-09        -0.000750        0.000030
# 568     -8.168461e-31     8.017848e-34        -0.000757        0.000025
# 567     -3.517894e-31     8.406984e-34        -0.000767        0.000027
# ..                ...              ...              ...             ...
# 333     -3.836324e-03     7.748767e-05        -0.004334        0.000114
# 6       -3.894000e-03     3.648414e-05        -0.004338        0.000036
# 330     -3.895968e-03     7.072418e-05        -0.004385        0.000047
# 339     -3.929904e-03     2.589977e-05        -0.004414        0.000030
# 327     -3.938207e-03     1.007243e-04        -0.004455        0.000081
#
# [648 rows x 6 columns]

# %%
for param_name in param_grid[0]:

    params = sorted(results_df['param_' + param_name].unique())
    means_train = [-results_df[results_df['param_' + param_name] == p]['mean_train_score'] for p in params]
    means_test = [-results_df[results_df['param_' + param_name] == p]['mean_test_score'] for p in params]

    # plot
    fig, axes = plt.subplots(1,2, figsize=(10,4))

    axes[0].boxplot(means_train)
    axes[0].plot(params.index(grid_search.best_params_[param_name])+1,
                 -grid_search.cv_results_['mean_train_score'][grid_search.best_index_], 'go')
    axes[0].set_xlabel(param_name)
    axes[0].set_ylabel('Train Score')
    
    axes[1].boxplot(means_test)
    axes[1].plot(params.index(grid_search.best_params_[param_name])+1,
                 -grid_search.cv_results_['mean_test_score'][grid_search.best_index_], 'go')    
    axes[1].set_xlabel(param_name)
    axes[1].set_ylabel('Test Score')
    
    # adding horizontal grid lines
    for ax in axes:
        ax.yaxis.grid(True)
        ax.set_xticks([x+1 for x in range(len(params))], labels=list(map(str, params)))
    
    plt.tight_layout()
    plt.show()

# %%
for param_name in param_grid[0]:
    
    results_dfg = results_df.groupby('param_' + param_name)
    params = results_dfg.groups.keys() # or params = results_df['param_' + param_name].unique()
    means_train = -results_dfg.mean()['mean_train_score']
    stds_train = results_dfg.std()['mean_train_score']
    means_test = -results_dfg.mean()['mean_test_score']
    stds_test = results_dfg.std()['mean_test_score']

    # plot
    fig, ax = plt.subplots()
    
    x = np.arange(len(params))  # the label locations
    width = 0.35  # the width of the bars

    ax.bar(x - width/2, means_train, width, yerr=stds_train, label = 'Train')
    ax.bar(x + width/2, means_test, width, yerr=stds_test, label = 'Test')
    ax.set_xticks(x, list(map(str, params)))
    ax.set_xlabel(param_name)
    ax.set_ylabel('Score')
    ax.legend()
    plt.show()

# %%
reg_best = grid_search.best_estimator_

print(grid_search.best_params_, end='\n')
print(grid_search.best_estimator_)
# Out:
# {'bootstrap': False, 'max_depth': 20, 'max_features': 0.6, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}
# RandomForestRegressor(bootstrap=False, max_depth=20, max_features=0.6,
#                       random_state=42)

# %%
cvres = grid_search.cv_results_
for mean_score, params in zip(cvres["mean_test_score"], cvres["params"]):
    print(np.sqrt(-mean_score), params)
# Out:
# 0.06555490558753015 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.4, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 50}
# 0.06452254957419155 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.4, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 75}
# 0.06436010836295161 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.4, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}
# 0.06472910418298572 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.4, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 50}
# 0.0639315006560404 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.4, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 75}
# 0.06393449808660698 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.4, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 100}
# 0.06586094611476641 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.4, 'min_samples_leaf': 1, 'min_samples_split': 8, 'n_estimators': 50}
# 0.06495287478254327 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.4, 'min_samples_leaf': 1, 'min_samples_split': 8, 'n_estimators': 75}
# 0.06449482461843642 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.4, 'min_samples_leaf': 1, 'min_samples_split': 8, 'n_estimators': 100}
# 0.06489990860779529 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.4, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 50}
# 0.06441024814848167 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.4, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 75}
# 0.06417134038245151 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.4, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 100}
# 0.06489990860779529 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.4, 'min_samples_leaf': 2, 'min_samples_split': 4, 'n_estimators': 50}
# 0.06441024814848167 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.4, 'min_samples_leaf': 2, 'min_samples_split': 4, 'n_estimators': 75}
# 0.06417134038245151 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.4, 'min_samples_leaf': 2, 'min_samples_split': 4, 'n_estimators': 100}
# 0.06551581789050084 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.4, 'min_samples_leaf': 2, 'min_samples_split': 8, 'n_estimators': 50}
# 0.06456435420729426 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.4, 'min_samples_leaf': 2, 'min_samples_split': 8, 'n_estimators': 75}
# 0.06414901954519131 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.4, 'min_samples_leaf': 2, 'min_samples_split': 8, 'n_estimators': 100}
# 0.06530425053697717 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.4, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 50}
# 0.06437892875118632 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.4, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 75}
# 0.06403907738504352 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.4, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 100}
# 0.06530425053697717 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.4, 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 50}
# 0.06437892875118632 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.4, 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 75}
# 0.06403907738504352 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.4, 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 100}
# 0.06530425053697717 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.4, 'min_samples_leaf': 4, 'min_samples_split': 8, 'n_estimators': 50}
# 0.06437892875118632 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.4, 'min_samples_leaf': 4, 'min_samples_split': 8, 'n_estimators': 75}
# 0.06403907738504352 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.4, 'min_samples_leaf': 4, 'min_samples_split': 8, 'n_estimators': 100}
# 0.04953295870811894 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.6, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 50}
# 0.04927308026489965 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.6, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 75}
# 0.04904401788353971 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.6, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}
# 0.04952762694012014 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.6, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 50}
# 0.049244684516668295 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.6, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 75}
# 0.04905967030394553 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.6, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 100}
# 0.049628251332756015 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.6, 'min_samples_leaf': 1, 'min_samples_split': 8, 'n_estimators': 50}
# 0.04933080094012637 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.6, 'min_samples_leaf': 1, 'min_samples_split': 8, 'n_estimators': 75}
# 0.04911214765777919 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.6, 'min_samples_leaf': 1, 'min_samples_split': 8, 'n_estimators': 100}
# 0.049517665351302365 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.6, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 50}
# 0.04921841713670512 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.6, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 75}
# 0.04901554408005474 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.6, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 100}
# 0.049517665351302365 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.6, 'min_samples_leaf': 2, 'min_samples_split': 4, 'n_estimators': 50}
# 0.04921841713670512 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.6, 'min_samples_leaf': 2, 'min_samples_split': 4, 'n_estimators': 75}
# 0.04901554408005474 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.6, 'min_samples_leaf': 2, 'min_samples_split': 4, 'n_estimators': 100}
# 0.04968780448470838 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.6, 'min_samples_leaf': 2, 'min_samples_split': 8, 'n_estimators': 50}
# 0.04934829061493426 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.6, 'min_samples_leaf': 2, 'min_samples_split': 8, 'n_estimators': 75}
# 0.04912488545360238 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.6, 'min_samples_leaf': 2, 'min_samples_split': 8, 'n_estimators': 100}
# 0.0494853277930582 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.6, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 50}
# 0.04921890725925868 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.6, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 75}
# 0.04904306376972079 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.6, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 100}
# 0.0494853277930582 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.6, 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 50}
# 0.04921890725925868 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.6, 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 75}
# 0.04904306376972079 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.6, 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 100}
# 0.0494853277930582 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.6, 'min_samples_leaf': 4, 'min_samples_split': 8, 'n_estimators': 50}
# 0.04921890725925868 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.6, 'min_samples_leaf': 4, 'min_samples_split': 8, 'n_estimators': 75}
# 0.04904306376972079 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.6, 'min_samples_leaf': 4, 'min_samples_split': 8, 'n_estimators': 100}
# 0.04980042118183108 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.8, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 50}
# 0.04968814197143527 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.8, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 75}
# 0.04959711697013177 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.8, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}
# 0.04984191741754955 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.8, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 50}
# 0.049731700076494856 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.8, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 75}
# 0.049647962383243226 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.8, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 100}
# 0.049819793145918154 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.8, 'min_samples_leaf': 1, 'min_samples_split': 8, 'n_estimators': 50}
# 0.04970957773187036 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.8, 'min_samples_leaf': 1, 'min_samples_split': 8, 'n_estimators': 75}
# 0.049612520903317504 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.8, 'min_samples_leaf': 1, 'min_samples_split': 8, 'n_estimators': 100}
# 0.0497269780966211 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.8, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 50}
# 0.04961136840427768 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.8, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 75}
# 0.049513875364295246 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.8, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 100}
# 0.0497269780966211 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.8, 'min_samples_leaf': 2, 'min_samples_split': 4, 'n_estimators': 50}
# 0.04961136840427768 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.8, 'min_samples_leaf': 2, 'min_samples_split': 4, 'n_estimators': 75}
# 0.049513875364295246 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.8, 'min_samples_leaf': 2, 'min_samples_split': 4, 'n_estimators': 100}
# 0.04969590243734432 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.8, 'min_samples_leaf': 2, 'min_samples_split': 8, 'n_estimators': 50}
# 0.04957307323893757 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.8, 'min_samples_leaf': 2, 'min_samples_split': 8, 'n_estimators': 75}
# 0.04947267824169076 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.8, 'min_samples_leaf': 2, 'min_samples_split': 8, 'n_estimators': 100}
# 0.049684203595532044 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.8, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 50}
# 0.049575770362410745 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.8, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 75}
# 0.049472831356496196 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.8, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 100}
# 0.049684203595532044 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.8, 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 50}
# 0.049575770362410745 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.8, 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 75}
# 0.049472831356496196 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.8, 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 100}
# 0.049684203595532044 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.8, 'min_samples_leaf': 4, 'min_samples_split': 8, 'n_estimators': 50}
# 0.049575770362410745 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.8, 'min_samples_leaf': 4, 'min_samples_split': 8, 'n_estimators': 75}
# 0.049472831356496196 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.8, 'min_samples_leaf': 4, 'min_samples_split': 8, 'n_estimators': 100}
# 0.05179340588727834 {'bootstrap': True, 'max_depth': 10, 'max_features': 1.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 50}
# 0.05169716864694617 {'bootstrap': True, 'max_depth': 10, 'max_features': 1.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 75}
# 0.051628826359448446 {'bootstrap': True, 'max_depth': 10, 'max_features': 1.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}
# 0.051792757565069285 {'bootstrap': True, 'max_depth': 10, 'max_features': 1.0, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 50}
# 0.051695708703965414 {'bootstrap': True, 'max_depth': 10, 'max_features': 1.0, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 75}
# 0.05162633629612042 {'bootstrap': True, 'max_depth': 10, 'max_features': 1.0, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 100}
# 0.0517958823888748 {'bootstrap': True, 'max_depth': 10, 'max_features': 1.0, 'min_samples_leaf': 1, 'min_samples_split': 8, 'n_estimators': 50}
# 0.05169748783345396 {'bootstrap': True, 'max_depth': 10, 'max_features': 1.0, 'min_samples_leaf': 1, 'min_samples_split': 8, 'n_estimators': 75}
# 0.05162848299828706 {'bootstrap': True, 'max_depth': 10, 'max_features': 1.0, 'min_samples_leaf': 1, 'min_samples_split': 8, 'n_estimators': 100}
# 0.05162335327563867 {'bootstrap': True, 'max_depth': 10, 'max_features': 1.0, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 50}
# 0.05152085429495958 {'bootstrap': True, 'max_depth': 10, 'max_features': 1.0, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 75}
# 0.05145286090804281 {'bootstrap': True, 'max_depth': 10, 'max_features': 1.0, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 100}
# 0.05162335327563867 {'bootstrap': True, 'max_depth': 10, 'max_features': 1.0, 'min_samples_leaf': 2, 'min_samples_split': 4, 'n_estimators': 50}
# 0.05152085429495958 {'bootstrap': True, 'max_depth': 10, 'max_features': 1.0, 'min_samples_leaf': 2, 'min_samples_split': 4, 'n_estimators': 75}
# 0.05145286090804281 {'bootstrap': True, 'max_depth': 10, 'max_features': 1.0, 'min_samples_leaf': 2, 'min_samples_split': 4, 'n_estimators': 100}
# 0.05162404029860141 {'bootstrap': True, 'max_depth': 10, 'max_features': 1.0, 'min_samples_leaf': 2, 'min_samples_split': 8, 'n_estimators': 50}
# 0.051521430225520616 {'bootstrap': True, 'max_depth': 10, 'max_features': 1.0, 'min_samples_leaf': 2, 'min_samples_split': 8, 'n_estimators': 75}
# 0.05145375112992557 {'bootstrap': True, 'max_depth': 10, 'max_features': 1.0, 'min_samples_leaf': 2, 'min_samples_split': 8, 'n_estimators': 100}
# 0.051620735790725576 {'bootstrap': True, 'max_depth': 10, 'max_features': 1.0, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 50}
max_depth': 20, 'max_features': 1.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 75}
# 0.03312605252526998 {'bootstrap': True, 'max_depth': 20, 'max_features': 1.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}
# 0.033938609831968364 {'bootstrap': True, 'max_depth': 20, 'max_features': 1.0, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 50}
# 0.03377209665608512 {'bootstrap': True, 'max_depth': 20, 'max_features': 1.0, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 75}
# 0.03365643806533514 {'bootstrap': True, 'max_depth': 20, 'max_features': 1.0, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 100}
# 0.035751403791431595 {'bootstrap': True, 'max_depth': 20, 'max_features': 1.0, 'min_samples_leaf': 1, 'min_samples_split': 8, 'n_estimators': 50}
# 0.03560942823816958 {'bootstrap': True, 'max_depth': 20, 'max_features': 1.0, 'min_samples_leaf': 1, 'min_samples_split': 8, 'n_estimators': 75}
# 0.035517438141658454 {'bootstrap': True, 'max_depth': 20, 'max_features': 1.0, 'min_samples_leaf': 1, 'min_samples_split': 8, 'n_estimators': 100}
# 0.03424964539214239 {'bootstrap': True, 'max_depth': 20, 'max_features': 1.0, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 50}
# 0.034089281380914514 {'bootstrap': True, 'max_depth': 20, 'max_features': 1.0, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 75}
# 0.0339877219010371 {'bootstrap': True, 'max_depth': 20, 'max_features': 1.0, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 100}
# 0.03424964539214239 {'bootstrap': True, 'max_depth': 20, 'max_features': 1.0, 'min_samples_leaf': 2, 'min_samples_split': 4, 'n_estimators': 50}
# 0.034089281380914514 {'bootstrap': True, 'max_depth': 20, 'max_features': 1.0, 'min_samples_leaf': 2, 'min_samples_split': 4, 'n_estimators': 75}
# 0.0339877219010371 {'bootstrap': True, 'max_depth': 20, 'max_features': 1.0, 'min_samples_leaf': 2, 'min_samples_split': 4, 'n_estimators': 100}
# 0.03598785153659689 {'bootstrap': True, 'max_depth': 20, 'max_features': 1.0, 'min_samples_leaf': 2, 'min_samples_split': 8, 'n_estimators': 50}
# 0.03583764119346491 {'bootstrap': True, 'max_depth': 20, 'max_features': 1.0, 'min_samples_leaf': 2, 'min_samples_split': 8, 'n_estimators': 75}
# 0.03574837250654423 {'bootstrap': True, 'max_depth': 20, 'max_features': 1.0, 'min_samples_leaf': 2, 'min_samples_split': 8, 'n_estimators': 100}
# 0.03705256658172794 {'bootstrap': True, 'max_depth': 20, 'max_features': 1.0, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 50}
# 0.03693562201519593 {'bootstrap': True, 'max_depth': 20, 'max_features': 1.0, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 75}
# 0.036854682259480354 {'bootstrap': True, 'max_depth': 20, 'max_features': 1.0, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 100}
# 0.03705256658172794 {'bootstrap': True, 'max_depth': 20, 'max_features': 1.0, 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 50}
# 0.03693562201519593 {'bootstrap': True, 'max_depth': 20, 'max_features': 1.0, 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 75}
# 0.036854682259480354 {'bootstrap': True, 'max_depth': 20, 'max_features': 1.0, 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 100}
# 0.03705256658172794 {'bootstrap': True, 'max_depth': 20, 'max_features': 1.0, 'min_samples_leaf': 4, 'min_samples_split': 8, 'n_estimators': 50}
# 0.03693562201519593 {'bootstrap': True, 'max_depth': 20, 'max_features': 1.0, 'min_samples_leaf': 4, 'min_samples_split': 8, 'n_estimators': 75}
# 0.036854682259480354 {'bootstrap': True, 'max_depth': 20, 'max_features': 1.0, 'min_samples_leaf': 4, 'min_samples_split': 8, 'n_estimators': 100}
# 0.031430204794155175 {'bootstrap': True, 'max_depth': 30, 'max_features': 0.4, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 50}
# 0.030624284922972485 {'bootstrap': True, 'max_depth': 30, 'max_features': 0.4, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 75}
# 0.030198370597897737 {'bootstrap': True, 'max_depth': 30, 'max_features': 0.4, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}
# 0.032310433288550135 {'bootstrap': True, 'max_depth': 30, 'max_features': 0.4, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 50}
# 0.03150275136199136 {'bootstrap': True, 'max_depth': 30, 'max_features': 0.4, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 75}
# 0.03117938337865202 {'bootstrap': True, 'max_depth': 30, 'max_features': 0.4, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 100}
# 0.035506262925552264 {'bootstrap': True, 'max_depth': 30, 'max_features': 0.4, 'min_samples_leaf': 1, 'min_samples_split': 8, 'n_estimators': 50}
# 0.034827042046899785 {'bootstrap': True, 'max_depth': 30, 'max_features': 0.4, 'min_samples_leaf': 1, 'min_samples_split': 8, 'n_estimators': 75}
# 0.034429927667199184 {'bootstrap': True, 'max_depth': 30, 'max_features': 0.4, 'min_samples_leaf': 1, 'min_samples_split': 8, 'n_estimators': 100}
# 0.033237991998680806 {'bootstrap': True, 'max_depth': 30, 'max_features': 0.4, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 50}
# 0.03244480872869686 {'bootstrap': True, 'max_depth': 30, 'max_features': 0.4, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 75}
# 0.03211460589768805 {'bootstrap': True, 'max_depth': 30, 'max_features': 0.4, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 100}
# 0.033237991998680806 {'bootstrap': True, 'max_depth': 30, 'max_features': 0.4, 'min_samples_leaf': 2, 'min_samples_split': 4, 'n_estimators': 50}
# 0.03244480872869686 {'bootstrap': True, 'max_depth': 30, 'max_features': 0.4, 'min_samples_leaf': 2, 'min_samples_split': 4, 'n_estimators': 75}
# 0.03211460589768805 {'bootstrap': True, 'max_depth': 30, 'max_features': 0.4, 'min_samples_leaf': 2, 'min_samples_split': 4, 'n_estimators': 100}
# 0.03584822963286523 {'bootstrap': True, 'max_depth': 30, 'max_features': 0.4, 'min_samples_leaf': 2, 'min_samples_split': 8, 'n_estimators': 50}
# 0.03505237357435313 {'bootstrap': True, 'max_depth': 30, 'max_features': 0.4, 'min_samples_leaf': 2, 'min_samples_split': 8, 'n_estimators': 75}
# 0.034796961445441615 {'bootstrap': True, 'max_depth': 30, 'max_features': 0.4, 'min_samples_leaf': 2, 'min_samples_split': 8, 'n_estimators': 100}
# 0.0368372282509061 {'bootstrap': True, 'max_depth': 30, 'max_features': 0.4, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 50}
# 0.036234958951901784 {'bootstrap': True, 'max_depth': 30, 'max_features': 0.4, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 75}
# 0.03590823704765073 {'bootstrap': True, 'max_depth': 30, 'max_features': 0.4, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 100}
# 0.0368372282509061 {'bootstrap': True, 'max_depth': 30, 'max_features': 0.4, 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 50}
# 0.036234958951901784 {'bootstrap': True, 'max_depth': 30, 'max_features': 0.4, 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 75}
# 0.03590823704765073 {'bootstrap': True, 'max_depth': 30, 'max_features': 0.4, 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 100}
# 0.0368372282509061 {'bootstrap': True, 'max_depth': 30, 'max_features': 0.4, 'min_samples_leaf': 4, 'min_samples_split': 8, 'n_estimators': 50}
# 0.036234958951901784 {'bootstrap': True, 'max_depth': 30, 'max_features': 0.4, 'min_samples_leaf': 4, 'min_samples_split': 8, 'n_estimators': 75}
# 0.03590823704765073 {'bootstrap': True, 'max_depth': 30, 'max_features': 0.4, 'min_samples_leaf': 4, 'min_samples_split': 8, 'n_estimators': 100}
# 0.028971971155757767 {'bootstrap': True, 'max_depth': 30, 'max_features': 0.6, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 50}
# 0.028596616872065352 {'bootstrap': True, 'max_depth': 30, 'max_features': 0.6, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 75}
# 0.028362768671564367 {'bootstrap': True, 'max_depth': 30, 'max_features': 0.6, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}
# 0.02951334818855484 {'bootstrap': True, 'max_depth': 30, 'max_features': 0.6, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 50}
# 0.029138737448317003 {'bootstrap': True, 'max_depth': 30, 'max_features': 0.6, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 75}
# 0.029008283124970263 {'bootstrap': True, 'max_depth': 30, 'max_features': 0.6, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 100}
# 0.03141153543089263 {'bootstrap': True, 'max_depth': 30, 'max_features': 0.6, 'min_samples_leaf': 1, 'min_samples_split': 8, 'n_estimators': 50}
# 0.03114948108114244 {'bootstrap': True, 'max_depth': 30, 'max_features': 0.6, 'min_samples_leaf': 1, 'min_samples_split': 8, 'n_estimators': 75}
# 0.030979680014264512 {'bootstrap': True, 'max_depth': 30, 'max_features': 0.6, 'min_samples_leaf': 1, 'min_samples_split': 8, 'n_estimators': 100}
# 0.029877170977780667 {'bootstrap': True, 'max_depth': 30, 'max_features': 0.6, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 50}
# 0.0296020908712136 {'bootstrap': True, 'max_depth': 30, 'max_features': 0.6, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 75}
# 0.02942462164321121 {'bootstrap': True, 'max_depth': 30, 'max_features': 0.6, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 100}
# 0.029877170977780667 {'bootstrap': True, 'max_depth': 30, 'max_features': 0.6, 'min_samples_leaf': 2, 'min_samples_split': 4, 'n_estimators': 50}
# 0.0296020908712136 {'bootstrap': True, 'max_depth': 30, 'max_features': 0.6, 'min_samples_leaf': 2, 'min_samples_split': 4, 'n_estimators': 75}
# 0.02942462164321121 {'bootstrap': True, 'max_depth': 30, 'max_features': 0.6, 'min_samples_leaf': 2, 'min_samples_split': 4, 'n_estimators': 100}
# 0.03181564688836135 {'bootstrap': True, 'max_depth': 30, 'max_features': 0.6, 'min_samples_leaf': 2, 'min_samples_split': 8, 'n_estimators': 50}
# 0.031506753189139786 {'bootstrap': True, 'max_depth': 30, 'max_features': 0.6, 'min_samples_leaf': 2, 'min_samples_split': 8, 'n_estimators': 75}
# 0.03131219226714169 {'bootstrap': True, 'max_depth': 30, 'max_features': 0.6, 'min_samples_leaf': 2, 'min_samples_split': 8, 'n_estimators': 100}
# 0.032563911260447234 {'bootstrap': True, 'max_depth': 30, 'max_features': 0.6, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 50}
# 0.03229379716665326 {'bootstrap': True, 'max_depth': 30, 'max_features': 0.6, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 75}
# 0.03209853214184129 {'bootstrap': True, 'max_depth': 30, 'max_features': 0.6, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 100}
# 0.032563911260447234 {'bootstrap': True, 'max_depth': 30, 'max_features': 0.6, 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 50}
# 0.03229379716665326 {'bootstrap': True, 'max_depth': 30, 'max_features': 0.6, 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 75}
# 0.03209853214184129 {'bootstrap': True, 'max_depth': 30, 'max_features': 0.6, 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 100}
# 0.032563911260447234 {'bootstrap': True, 'max_depth': 30, 'max_features': 0.6, 'min_samples_leaf': 4, 'min_samples_split': 8, 'n_estimators': 50}
# 0.03229379716665326 {'bootstrap': True, 'max_depth': 30, 'max_features': 0.6, 'min_samples_leaf': 4, 'min_samples_split': 8, 'n_estimators': 75}
# 0.03209853214184129 {'bootstrap': True, 'max_depth': 30, 'max_features': 0.6, 'min_samples_leaf': 4, 'min_samples_split': 8, 'n_estimators': 100}
# 0.03184849603047185 {'bootstrap': True, 'max_depth': 30, 'max_features': 0.8, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 50}
# 0.03160222372499747 {'bootstrap': True, 'max_depth': 30, 'max_features': 0.8, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 75}
# 0.03147820615663522 {'bootstrap': True, 'max_depth': 30, 'max_features': 0.8, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}
# 0.032406421147739436 {'bootstrap': True, 'max_depth': 30, 'max_features': 0.8, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 50}
# 0.032184496702634846 {'bootstrap': True, 'max_depth': 30, 'max_features': 0.8, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 75}
# 0.032062931948928515 {'bootstrap': True, 'max_depth': 30, 'max_features': 0.8, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 100}
# 0.03421587095630666 {'bootstrap': True, 'max_depth': 30, 'max_features': 0.8, 'min_samples_leaf': 1, 'min_samples_split': 8, 'n_estimators': 50}
# 0.03398972351050547 {'bootstrap': True, 'max_depth': 30, 'max_features': 0.8, 'min_samples_leaf': 1, 'min_samples_split': 8, 'n_estimators': 75}
# 0.03389970525056501 {'bootstrap': True, 'max_depth': 30, 'max_features': 0.8, 'min_samples_leaf': 1, 'min_samples_split': 8, 'n_estimators': 100}
# 0.03283239342350382 {'bootstrap': True, 'max_depth': 30, 'max_features': 0.8, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 50}
# 0.03264285861921928 {'bootstrap': True, 'max_depth': 30, 'max_features': 0.8, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 75}
# 0.03250849301860499 {'bootstrap': True, 'max_depth': 30, 'max_features': 0.8, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 100}
# 0.03283239342350382 {'bootstrap': True, 'max_depth': 30, 'max_features': 0.8, 'min_samples_leaf': 2, 'min_samples_split': 4, 'n_estimators': 50}
# 0.03264285861921928 {'bootstrap': True, 'max_depth': 30, 'max_features': 0.8, 'min_samples_leaf': 2, 'min_samples_split': 4, 'n_estimators': 75}
# 0.03250849301860499 {'bootstrap': True, 'max_depth': 30, 'max_features': 0.8, 'min_samples_leaf': 2, 'min_samples_split': 4, 'n_estimators': 100}
# 0.03453833341407547 {'bootstrap': True, 'max_depth': 30, 'max_features': 0.8, 'min_samples_leaf': 2, 'min_samples_split': 8, 'n_estimators': 50}
# 0.03433223224786134 {'bootstrap': True, 'max_depth': 30, 'max_features': 0.8, 'min_samples_leaf': 2, 'min_samples_split': 8, 'n_estimators': 75}
# 0.034222863521702215 {'bootstrap': True, 'max_depth': 30, 'max_features': 0.8, 'min_samples_leaf': 2, 'min_samples_split': 8, 'n_estimators': 100}
# 0.03550310572370111 {'bootstrap': True, 'max_depth': 30, 'max_features': 0.8, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 50}
# 0.035333711720383076 {'bootstrap': True, 'max_depth': 30, 'max_features': 0.8, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 75}
# 0.03523631650157757 {'bootstrap': True, 'max_depth': 30, 'max_features': 0.8, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 100}
# 0.03550310572370111 {'bootstrap': True, 'max_depth': 30, 'max_features': 0.8, 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 50}
# 0.035333711720383076 {'bootstrap': True, 'max_depth': 30, 'max_features': 0.8, 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 75}
# 0.03523631650157757 {'bootstrap': True, 'max_depth': 30, 'max_features': 0.8, 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 100}
# 0.03550310572370111 {'bootstrap': True, 'max_depth': 30, 'max_features': 0.8, 'min_samples_leaf': 4, 'min_samples_split': 8, 'n_estimators': 50}
# 0.035333711720383076 {'bootstrap': True, 'max_depth': 30, 'max_features': 0.8, 'min_samples_leaf': 4, 'min_samples_split': 8, 'n_estimators': 75}
# 0.03523631650157757 {'bootstrap': True, 'max_depth': 30, 'max_features': 0.8, 'min_samples_leaf': 4, 'min_samples_split': 8, 'n_estimators': 100}
# 0.03341349107862045 {'bootstrap': True, 'max_depth': 30, 'max_features': 1.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 50}
# 0.033231727223879716 {'bootstrap': True, 'max_depth': 30, 'max_features': 1.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 75}
# 0.0331169887382032 {'bootstrap': True, 'max_depth': 30, 'max_features': 1.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}
# 0.03393436414309458 {'bootstrap': True, 'max_depth': 30, 'max_features': 1.0, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 50}
# 0.03377105268452343 {'bootstrap': True, 'max_depth': 30, 'max_features': 1.0, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 75}
# 0.03365387561913953 {'bootstrap': True, 'max_depth': 30, 'max_features': 1.0, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 100}
# 0.03575177507121747 {'bootstrap': True, 'max_depth': 30, 'max_features': 1.0, 'min_samples_leaf': 1, 'min_samples_split': 8, 'n_estimators': 50}
# 0.035609708761895495 {'bootstrap': True, 'max_depth': 30, 'max_features': 1.0, 'min_samples_leaf': 1, 'min_samples_split': 8, 'n_estimators': 75}
# 0.035517650682121225 {'bootstrap': True, 'max_depth': 30, 'max_features': 1.0, 'min_samples_leaf': 1, 'min_samples_split': 8, 'n_estimators': 100}
# 0.034250172996325386 {'bootstrap': True, 'max_depth': 30, 'max_features': 1.0, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 50}
# 0.03408997415374139 {'bootstrap': True, 'max_depth': 30, 'max_features': 1.0, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 75}
# 0.03398798040428646 {'bootstrap': True, 'max_depth': 30, 'max_features': 1.0, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 100}
# 0.034250172996325386 {'bootstrap': True, 'max_depth': 30, 'max_features': 1.0, 'min_samples_leaf': 2, 'min_samples_split': 4, 'n_estimators': 50}
# 0.03408997415374139 {'bootstrap': True, 'max_depth': 30, 'max_features': 1.0, 'min_samples_leaf': 2, 'min_samples_split': 4, 'n_estimators': 75}
# 0.03398798040428646 {'bootstrap': True, 'max_depth': 30, 'max_features': 1.0, 'min_samples_leaf': 2, 'min_samples_split': 4, 'n_estimators': 100}
# 0.03598785153659689 {'bootstrap': True, 'max_depth': 30, 'max_features': 1.0, 'min_samples_leaf': 2, 'min_samples_split': 8, 'n_estimators': 50}
# 0.03583764119346491 {'bootstrap': True, 'max_depth': 30, 'max_features': 1.0, 'min_samples_leaf': 2, 'min_samples_split': 8, 'n_estimators': 75}
# 0.03574837250654423 {'bootstrap': True, 'max_depth': 30, 'max_features': 1.0, 'min_samples_leaf': 2, 'min_samples_split': 8, 'n_estimators': 100}
# 0.03705256658172794 {'bootstrap': True, 'max_depth': 30, 'max_features': 1.0, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 50}
# 0.03693562201519593 {'bootstrap': True, 'max_depth': 30, 'max_features': 1.0, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 75}
# 0.036854682259480354 {'bootstrap': True, 'max_depth': 30, 'max_features': 1.0, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 100}
# 0.03705256658172794 {'bootstrap': True, 'max_depth': 30, 'max_features': 1.0, 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 50}
# 0.03693562201519593 {'bootstrap': True, 'max_depth': 30, 'max_features': 1.0, 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 75}
# 0.036854682259480354 {'bootstrap': True, 'max_depth': 30, 'max_features': 1.0, 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 100}
# 0.03705256658172794 {'bootstrap': True, 'max_depth': 30, 'max_features': 1.0, 'min_samples_leaf': 4, 'min_samples_split': 8, 'n_estimators': 50}
# 0.03693562201519593 {'bootstrap': True, 'max_depth': 30, 'max_features': 1.0, 'min_samples_leaf': 4, 'min_samples_split': 8, 'n_estimators': 75}
# 0.036854682259480354 {'bootstrap': True, 'max_depth': 30, 'max_features': 1.0, 'min_samples_leaf': 4, 'min_samples_split': 8, 'n_estimators': 100}
# 0.0657953097284831 {'bootstrap': False, 'max_depth': 10, 'max_features': 0.4, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 50}
# 0.06521464372321781 {'bootstrap': False, 'max_depth': 10, 'max_features': 0.4, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 75}
# 0.06501851648665509 {'bootstrap': False, 'max_depth': 10, 'max_features': 0.4, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}
# 0.06674811116377014 {'bootstrap': False, 'max_depth': 10, 'max_features': 0.4, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 50}
# 0.06522588187082803 {'bootstrap': False, 'max_depth': 10, 'max_features': 0.4, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 75}
# ...
# 0.048932729065714844 {'bootstrap': False, 'max_depth': 20, 'max_features': 1.0, 'min_samples_leaf': 4, 'min_samples_split': 8, 'n_estimators': 100}
# 0.029095086759110253 {'bootstrap': False, 'max_depth': 30, 'max_features': 0.4, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 50}
# 0.02835670267370118 {'bootstrap': False, 'max_depth': 30, 'max_features': 0.4, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 75}
# 0.028015183491386594 {'bootstrap': False, 'max_depth': 30, 'max_features': 0.4, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}
# 0.029991363095504295 {'bootstrap': False, 'max_depth': 30, 'max_features': 0.4, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 50}
# 0.02931406404488981 {'bootstrap': False, 'max_depth': 30, 'max_features': 0.4, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 75}
# 0.028962832971826783 {'bootstrap': False, 'max_depth': 30, 'max_features': 0.4, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 100}
# 0.03248827502051535 {'bootstrap': False, 'max_depth': 30, 'max_features': 0.4, 'min_samples_leaf': 1, 'min_samples_split': 8, 'n_estimators': 50}
# 0.03185211496961035 {'bootstrap': False, 'max_depth': 30, 'max_features': 0.4, 'min_samples_leaf': 1, 'min_samples_split': 8, 'n_estimators': 75}
# 0.03154589436262748 {'bootstrap': False, 'max_depth': 30, 'max_features': 0.4, 'min_samples_leaf': 1, 'min_samples_split': 8, 'n_estimators': 100}
# 0.030731442796683908 {'bootstrap': False, 'max_depth': 30, 'max_features': 0.4, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 50}
# 0.03005921505700128 {'bootstrap': False, 'max_depth': 30, 'max_features': 0.4, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 75}
# 0.02969092109185173 {'bootstrap': False, 'max_depth': 30, 'max_features': 0.4, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 100}
# 0.030731442796683908 {'bootstrap': False, 'max_depth': 30, 'max_features': 0.4, 'min_samples_leaf': 2, 'min_samples_split': 4, 'n_estimators': 50}
# 0.03005921505700128 {'bootstrap': False, 'max_depth': 30, 'max_features': 0.4, 'min_samples_leaf': 2, 'min_samples_split': 4, 'n_estimators': 75}
# 0.02969092109185173 {'bootstrap': False, 'max_depth': 30, 'max_features': 0.4, 'min_samples_leaf': 2, 'min_samples_split': 4, 'n_estimators': 100}
# 0.033081674770786176 {'bootstrap': False, 'max_depth': 30, 'max_features': 0.4, 'min_samples_leaf': 2, 'min_samples_split': 8, 'n_estimators': 50}
# 0.0325092425090101 {'bootstrap': False, 'max_depth': 30, 'max_features': 0.4, 'min_samples_leaf': 2, 'min_samples_split': 8, 'n_estimators':

#    'min_samples_leaf': 4,
#    'min_samples_split': 2,
#    'n_estimators': 50}),
#  (0.0529186848402276,
#   {'bootstrap': False,
#    'max_depth': 10,
#    'max_features': 0.8,
#    'min_samples_leaf': 4,
#    'min_samples_split': 4,
#    'n_estimators': 50}),
#  (0.0529186848402276,
#   {'bootstrap': False,
#    'max_depth': 10,
#    'max_features': 0.8,
#    'min_samples_leaf': 4,
#    'min_samples_split': 8,
#    'n_estimators': 50}),
#  (0.05295901001228383,
#   {'bootstrap': False,
#    'max_depth': 10,
#    'max_features': 0.8,
#    'min_samples_leaf': 2,
#    'min_samples_split': 8,
#    'n_estimators': 50}),
#  (0.05300148650828215,
#   {'bootstrap': False,
#    'max_depth': 10,
#    'max_features': 0.8,
#    'min_samples_leaf': 1,
#    'min_samples_split': 8,
#    'n_estimators': 100}),
#  (0.05301062567744209,
#   {'bootstrap': False,
#    'max_depth': 10,
#    'max_features': 0.8,
#    'min_samples_leaf': 1,
#    'min_samples_split': 2,
#    'n_estimators': 100}),
#  (0.05301093969405671,
#   {'bootstrap': False,
#    'max_depth': 10,
#    'max_features': 0.8,
#    'min_samples_leaf': 1,
#    'min_samples_split': 8,
#    'n_estimators': 75}),
#  (0.05303513542489418,
#   {'bootstrap': False,
#    'max_depth': 10,
#    'max_features': 0.8,
#    'min_samples_leaf': 1,
#    'min_samples_split': 4,
#    'n_estimators': 100}),
#  (0.05304738042517824,
#   {'bootstrap': False,
#    'max_depth': 10,
#    'max_features': 0.8,
#    'min_samples_leaf': 1,
#    'min_samples_split': 4,
#    'n_estimators': 75}),
#  (0.053063103166886574,
#   {'bootstrap': False,
#    'max_depth': 10,
#    'max_features': 0.8,
#    'min_samples_leaf': 1,
#    'min_samples_split': 2,
#    'n_estimators': 75}),
#  (0.053084243716498336,
#   {'bootstrap': False,
#    'max_depth': 10,
#    'max_features': 0.8,
#    'min_samples_leaf': 1,
#    'min_samples_split': 4,
#    'n_estimators': 50}),
#  (0.05309410180187495,
#   {'bootstrap': False,
#    'max_depth': 10,
#    'max_features': 0.8,
#    'min_samples_leaf': 1,
#    'min_samples_split': 8,
#    'n_estimators': 50}),
#  (0.05312132165616226,
#   {'bootstrap': False,
#    'max_depth': 10,
#    'max_features': 0.8,
#    'min_samples_leaf': 1,
#    'min_samples_split': 2,
#    'n_estimators': 50}),
#  (0.06337374276451789,
#   {'bootstrap': False,
#    'max_depth': 10,
#    'max_features': 1.0,
#    'min_samples_leaf': 4,
#    'min_samples_split': 2,
#    'n_estimators': 100}),
#  (0.06337374276451789,
#   {'bootstrap': False,
#    'max_depth': 10,
#    'max_features': 1.0,
#    'min_samples_leaf': 4,
#    'min_samples_split': 4,
#    'n_estimators': 100}),
#  (0.06337374276451789,
#   {'bootstrap': False,
#    'max_depth': 10,
#    'max_features': 1.0,
#    'min_samples_leaf': 4,
#    'min_samples_split': 8,
#    'n_estimators': 100}),
#  (0.0633737427645179,
#   {'bootstrap': False,
#    'max_depth': 10,
#    'max_features': 1.0,
#    'min_samples_leaf': 4,
#    'min_samples_split': 2,
#    'n_estimators': 50}),
#  (0.0633737427645179,
#   {'bootstrap': False,
#    'max_depth': 10,
#    'max_features': 1.0,
#    'min_samples_leaf': 4,
#    'min_samples_split': 2,
#    'n_estimators': 75}),
#  (0.0633737427645179,
#   {'bootstrap': False,
#    'max_depth': 10,
#    'max_features': 1.0,
#    'min_samples_leaf': 4,
#    'min_samples_split': 4,
#    'n_estimators': 50}),
#  (0.0633737427645179,
#   {'bootstrap': False,
#    'max_depth': 10,
#    'max_features': 1.0,
#    'min_samples_leaf': 4,
#    'min_samples_split': 4,
#    'n_estimators': 75}),
#  (0.0633737427645179,
#   {'bootstrap': False,
#    'max_depth': 10,
#    'max_features': 1.0,
#    'min_samples_leaf': 4,
#    'min_samples_split': 8,
#    'n_estimators': 50}),
#  (0.0633737427645179,
#   {'bootstrap': False,
#    'max_depth': 10,
#    'max_features': 1.0,
#    'min_samples_leaf': 4,
#    'min_samples_split': 8,
#    'n_estimators': 75}),
#  (0.06351091733234071,
#   {'bootstrap': False,
#    'max_depth': 10,
#    'max_features': 1.0,
#    'min_samples_leaf': 2,
#    'min_samples_split': 2,
#    'n_estimators': 100}),
#  (0.06351091733234071,
#   {'bootstrap': False,
#    'max_depth': 10,
#    'max_features': 1.0,
#    'min_samples_leaf': 2,
#    'min_samples_split': 4,
#    'n_estimators': 100}),
#  (0.06351091733234071,
#   {'bootstrap': False,
#    'max_depth': 10,
#    'max_features': 1.0,
#    'min_samples_leaf': 2,
#    'min_samples_split': 8,
#    'n_estimators': 100}),
#  (0.06351094481157878,
#   {'bootstrap': False,
#    'max_depth': 10,
#    'max_features': 1.0,
#    'min_samples_leaf': 2,
#    'min_samples_split': 2,
#    'n_estimators': 50}),
#  (0.06351094481157878,
#   {'bootstrap': False,
#    'max_depth': 10,
#    'max_features': 1.0,
#    'min_samples_leaf': 2,
#    'min_samples_split': 2,
#    'n_estimators': 75}),
#  (0.06351094481157878,
#   {'bootstrap': False,
#    'max_depth': 10,
#    'max_features': 1.0,
#    'min_samples_leaf': 2,
#    'min_samples_split': 4,
#    'n_estimators': 50}),
#  (0.06351094481157878,
#   {'bootstrap': False,
#    'max_depth': 10,
#    'max_features': 1.0,
#    'min_samples_leaf': 2,
#    'min_samples_split': 4,
#    'n_estimators': 75}),
#  (0.06351094481157878,
#   {'bootstrap': False,
#    'max_depth': 10,
#    'max_features': 1.0,
#    'min_samples_leaf': 2,
#    'min_samples_split': 8,
#    'n_estimators': 50}),
#  (0.06351094481157878,
#   {'bootstrap': False,
#    'max_depth': 10,
#    'max_features': 1.0,
#    'min_samples_leaf': 2,
#    'min_samples_split': 8,
#    'n_estimators': 75}),
#  (0.0636825564735014,
#   {'bootstrap': False,
#    'max_depth': 10,
#    'max_features': 1.0,
#    'min_samples_leaf': 1,
#    'min_samples_split': 8,
#    'n_estimators': 75}),
#  (0.0636849567887546,
#   {'bootstrap': False,
#    'max_depth': 10,
#    'max_features': 1.0,
#    'min_samples_leaf': 1,
#    'min_samples_split': 2,
#    'n_estimators': 75}),
#  (0.0636849567887546,
#   {'bootstrap': False,
#    'max_depth': 10,
#    'max_features': 1.0,
#    'min_samples_leaf': 1,
#    'min_samples_split': 4,
#    'n_estimators': 75}),
#  (0.06368599456667948,
#   {'bootstrap': False,
#    'max_depth': 10,
#    'max_features': 1.0,
#    'min_samples_leaf': 1,
#    'min_samples_split': 8,
#    'n_estimators': 50}),
#  (0.063686051010075,
#   {'bootstrap': False,
#    'max_depth': 10,
#    'max_features': 1.0,
#    'min_samples_leaf': 1,
#    'min_samples_split': 8,
#    'n_estimators': 100}),
#  (0.06368737720300637,
#   {'bootstrap': False,
#    'max_depth': 10,
#    'max_features': 1.0,
#    'min_samples_leaf': 1,
#    'min_samples_split': 2,
#    'n_estimators': 100}),
#  (0.06368737720300637,
#   {'bootstrap': False,
#    'max_depth': 10,
#    'max_features': 1.0,
#    'min_samples_leaf': 1,
#    'min_samples_split': 4,
#    'n_estimators': 100}),
#  (0.0636880887826734,
#   {'bootstrap': False,
#    'max_depth': 10,
#    'max_features': 1.0,
#    'min_samples_leaf': 1,
#    'min_samples_split': 2,
#    'n_estimators': 50}),
#  (0.0636880887826734,
#   {'bootstrap': False,
#    'max_depth': 10,
#    'max_features': 1.0,
#    'min_samples_leaf': 1,
#    'min_samples_split': 4,
#    'n_estimators': 50}),
#  (0.0639315006560404,
#   {'bootstrap': True,
#    'max_depth': 10,
#    'max_features': 0.4,
#    'min_samples_leaf': 1,
#    'min_samples_split': 4,
#    'n_estimators': 75}),
#  (0.06393449808660698,
#   {'bootstrap': True,
#    'max_depth': 10,
#    'max_features': 0.4,
#    'min_samples_leaf': 1,
#    'min_samples_split': 4,
#    'n_estimators': 100}),
#  (0.06403907738504352,
#   {'bootstrap': True,
#    'max_depth': 10,
#    'max_features': 0.4,
#    'min_samples_leaf': 4,
#    'min_samples_split': 2,
#    'n_estimators': 100}),
#  (0.06403907738504352,
#   {'bootstrap': True,
#    'max_depth': 10,
#    'max_features': 0.4,
#    'min_samples_leaf': 4,
#    'min_samples_split': 4,
#    'n_estimators': 100}),
#  (0.06403907738504352,
#   {'bootstrap': True,
#    'max_depth': 10,
#    'max_features': 0.4,
#    'min_samples_leaf': 4,
#    'min_samples_split': 8,
#    'n_estimators': 100}),
#  (0.06414901954519131,
#   {'bootstrap': True,
#    'max_depth': 10,
#    'max_features': 0.4,
#    'min_samples_leaf': 2,
#    'min_samples_split': 8,
#    'n_estimators': 100}),
#  (0.06417134038245151,
#   {'bootstrap': True,
#    'max_depth': 10,
#    'max_features': 0.4,
#    'min_samples_leaf': 2,
#    'min_samples_split': 2,
#    'n_estimators': 100}),
#  (0.06417134038245151,
#   {'bootstrap': True,
#    'max_depth': 10,
#    'max_features': 0.4,
#    'min_samples_leaf': 2,
#    'min_samples_split': 4,
#    'n_estimators': 100}),
#  (0.06436010836295161,
#   {'bootstrap': True,
#    'max_depth': 10,
#    'max_features': 0.4,
#    'min_samples_leaf': 1,
#    'min_samples_split': 2,
#    'n_estimators': 100}),
#  (0.06437892875118632,
#   {'bootstrap': True,
#    'max_depth': 10,
#    'max_features': 0.4,
#    'min_samples_leaf': 4,
#    'min_samples_split': 2,
#    'n_estimators': 75}),
#  (0.06437892875118632,
#   {'bootstrap': True,
#    'max_depth': 10,
#    'max_features': 0.4,
#    'min_samples_leaf': 4,
#    'min_samples_split': 4,
#    'n_estimators': 75}),
#  (0.06437892875118632,
#   {'bootstrap': True,
#    'max_depth': 10,
#    'max_features': 0.4,
#    'min_samples_leaf': 4,
#    'min_samples_split': 8,
#    'n_estimators': 75}),
#  (0.06441024814848167,
#   {'bootstrap': True,
#    'max_depth': 10,
#    'max_features': 0.4,
#    'min_samples_leaf': 2,
#    'min_samples_split': 2,
#    'n_estimators': 75}),
#  (0.06441024814848167,
#   {'bootstrap': True,
#    'max_depth': 10,
#    'max_features': 0.4,
#    'min_samples_leaf': 2,
#    'min_samples_split': 4,
#    'n_estimators': 75}),
#  (0.06449482461843642,
#   {'bootstrap': True,
#    'max_depth': 10,
#    'max_features': 0.4,
#    'min_samples_leaf': 1,
#    'min_samples_split': 8,
#    'n_estimators': 100}),
#  (0.06452254957419155,
#   {'bootstrap': True,
#    'max_depth': 10,
#    'max_features': 0.4,
#    'min_samples_leaf': 1,
#    'min_samples_split': 2,
#    'n_estimators': 75}),
#  (0.06456435420729426,
#   {'bootstrap': True,
#    'max_depth': 10,
#    'max_features': 0.4,
#    'min_samples_leaf': 2,
#    'min_samples_split': 8,
#    'n_estimators': 75}),
#  (0.06472910418298572,
#   {'bootstrap': True,
#    'max_depth': 10,
#    'max_features': 0.4,
#    'min_samples_leaf': 1,
#    'min_samples_split': 4,
#    'n_estimators': 50}),
#  (0.06489799314646366,
#   {'bootstrap': False,
#    'max_depth': 10,
#    'max_features': 0.4,
#    'min_samples_leaf': 4,
#    'min_samples_split': 2,
#    'n_estimators': 75}),
#  (0.06489799314646366,
#   {'bootstrap': False,
#    'max_depth': 10,
#    'max_features': 0.4,
#    'min_samples_leaf': 4,
#    'min_samples_split': 4,
#    'n_estimators': 75}),
#  (0.06489799314646366,
#   {'bootstrap': False,
#    'max_depth': 10,
#    'max_features': 0.4,
#    'min_samples_leaf': 4,
#    'min_samples_split': 8,
#    'n_estimators': 75}),
#  (0.06489990860779529,
#   {'bootstrap': True,
#    'max_depth': 10,
#    'max_features': 0.4,
#    'min_samples_leaf': 2,
#    'min_samples_split': 2,
#    'n_estimators': 50}),
#  (0.06489990860779529,
#   {'bootstrap': True,
#    'max_depth': 10,
#    'max_features': 0.4,
#    'min_samples_leaf': 2,
#    'min_samples_split': 4,
#    'n_estimators': 50}),
#  (0.06495287478254327,
#   {'bootstrap': True,
#    'max_depth': 10,
#    'max_features': 0.4,
#    'min_samples_leaf': 1,
#    'min_samples_split': 8,
#    'n_estimators': 75}),
#  (0.06499917112140507,
#   {'bootstrap': False,
#    'max_depth': 10,
#    'max_features': 0.4,
#    'min_samples_leaf': 4,
#    'min_samples_split': 2,
#    'n_estimators': 100}),
#  (0.06499917112140507,
#   {'bootstrap': False,
#    'max_depth': 10,
#    'max_features': 0.4,
#    'min_samples_leaf': 4,
#    'min_samples_split': 4,
#    'n_estimators': 100}),
#  (0.06499917112140507,
#   {'bootstrap': False,
#    'max_depth': 10,
#    'max_features': 0.4,
#    'min_samples_leaf': 4,
#    'min_samples_split': 8,
#    'n_estimators': 100}),
#  (0.06501851648665509,
#   {'bootstrap': False,
#    'max_depth': 10,
#    'max_features': 0.4,
#    'min_samples_leaf': 1,
#    'min_samples_split': 2,
#    'n_estimators': 100}),
#  (0.06515751788240287,
#   {'bootstrap': False,
#    'max_depth': 10,
#    'max_features': 0.4,
#    'min_samples_leaf': 1,
#    'min_samples_split': 8,
#    'n_estimators': 100}),
#  (0.06521464372321781,
#   {'bootstrap': False,
#    'max_depth': 10,
#    'max_features': 0.4,
#    'min_samples_leaf': 1,
#    'min_samples_split': 2,
#    'n_estimators': 75}),
#  (0.06522588187082803,
#   {'bootstrap': False,
#    'max_depth': 10,
#    'max_features': 0.4,
#    'min_samples_leaf': 1,
#    'min_samples_split': 4,
#    'n_estimators': 75}),
#  (0.06530425053697717,
#   {'bootstrap': True,
#    'max_depth': 10,
#    'max_features': 0.4,
#    'min_samples_leaf': 4,
#    'min_samples_split': 2,
#    'n_estimators': 50}),
#  (0.06530425053697717,
#   {'bootstrap': True,
#    'max_depth': 10,
#    'max_features': 0.4,
#    'min_samples_leaf': 4,
#    'min_samples_split': 4,
#    'n_estimators': 50}),
#  (0.06530425053697717,
#   {'bootstrap': True,
#    'max_depth': 10,
#    'max_features': 0.4,
#    'min_samples_leaf': 4,
#    'min_samples_split': 8,
#    'n_estimators': 50}),
#  (0.06533896593411137,
#   {'bootstrap': False,
#    'max_depth': 10,
#    'max_features': 0.4,
#    'min_samples_leaf': 2,
#    'min_samples_split': 2,
#    'n_estimators': 100}),
#  (0.06533896593411137,
#   {'bootstrap': False,
#    'max_depth': 10,
#    'max_features': 0.4,
#    'min_samples_leaf': 2,
#    'min_samples_split': 4,
#    'n_estimators': 100}),
#  (0.0653396238997605,
#   {'bootstrap': False,
#    'max_depth': 10,
#    'max_features': 0.4,
#    'min_samples_leaf': 1,
#    'min_samples_split': 4,
#    'n_estimators': 100}),
#  (0.06534643088393056,
#   {'bootstrap': False,
#    'max_depth': 10,
#    'max_features': 0.4,
#    'min_samples_leaf': 4,
#    'min_samples_split': 2,
#    'n_estimators': 50}),
#  (0.06534643088393056,
#   {'bootstrap': False,
#    'max_depth': 10,
#    'max_features': 0.4,
#    'min_samples_leaf': 4,
#    'min_samples_split': 4,
#    'n_estimators': 50}),
#  (0.06534643088393056,
#   {'bootstrap': False,
#    'max_depth': 10,
#    'max_features': 0.4,
#    'min_samples_leaf': 4,
#    'min_samples_split': 8,
#    'n_estimators': 50}),
#  (0.06541864605844604,
#   {'bootstrap': False,
#    'max_depth': 10,
#    'max_features': 0.4,
#    'min_samples_leaf': 2,
#    'min_samples_split': 2,
#    'n_estimators': 75}),
#  (0.06541864605844604,
#   {'bootstrap': False,
#    'max_depth': 10,
#    'max_features': 0.4,
#    'min_samples_leaf': 2,
#    'min_samples_split': 4,
#    'n_estimators': 75}),
#  (0.06547887676894876,
#   {'bootstrap': False,
#    'max_depth': 10,
#    'max_features': 0.4,
#    'min_samples_leaf': 1,
#    'min_samples_split': 8,
#    'n_estimators': 75}),
#  (0.06551581789050084,
#   {'bootstrap': True,
#    'max_depth': 10,
#    'max_features': 0.4,
#    'min_samples_leaf': 2,
#    'min_samples_split': 8,
#    'n_estimators': 50}),
#  (0.06553661974007452,
#   {'bootstrap': False,
#    'max_depth': 10,
#    'max_features': 0.4,
#    'min_samples_leaf': 2,
#    'min_samples_split': 8,
#    'n_estimators': 100}),
#  (0.06555490558753015,
#   {'bootstrap': True,
#    'max_depth': 10,
#    'max_features': 0.4,
#    'min_samples_leaf': 1,
#    'min_samples_split': 2,
#    'n_estimators': 50}),
#  (0.06568887016975795,
#   {'bootstrap': False,
#    'max_depth': 10,
#    'max_features': 0.4,
#    'min_samples_leaf': 2,
#    'min_samples_split': 8,
#    'n_estimators': 75}),
#  (0.0657953097284831,
#   {'bootstrap': False,
#    'max_depth': 10,
#    'max_features': 0.4,
#    'min_samples_leaf': 1,
#    'min_samples_split': 2,
#    'n_estimators': 50}),
#  (0.06582993716134872,
#   {'bootstrap': False,
#    'max_depth': 10,
#    'max_features': 0.4,
#    'min_samples_leaf': 2,
#    'min_samples_split': 2,
#    'n_estimators': 50}),
#  (0.06582993716134872,
#   {'bootstrap': False,
#    'max_depth': 10,
#    'max_features': 0.4,
#    'min_samples_leaf': 2,
#    'min_samples_split': 4,
#    'n_estimators': 50}),
#  (0.06586094611476641,
#   {'bootstrap': True,
#    'max_depth': 10,
#    'max_features': 0.4,
#    'min_samples_leaf': 1,
#    'min_samples_split': 8,
#    'n_estimators': 50}),
#  (0.06622259294573979,
#   {'bootstrap': False,
#    'max_depth': 10,
#    'max_features': 0.4,
#    'min_samples_leaf': 1,
#    'min_samples_split': 8,
#    'n_estimators': 50}),
#  (0.0664401927242684,
#   {'bootstrap': False,
#    'max_depth': 10,
#    'max_features': 0.4,
#    'min_samples_leaf': 2,
#    'min_samples_split': 8,
#    'n_estimators': 50}),
#  (0.06674811116377014,
#   {'bootstrap': False,
#    'max_depth': 10,
#    'max_features': 0.4,
#    'min_samples_leaf': 1,
#    'min_samples_split': 4,
#    'n_estimators': 50})]

# %%
sorted(zip(reg_best.feature_importances_, inputs), reverse=True)
# Out:
# [(0.34658274447096726, '0_Na'),
#  (0.3359468757340511, '0_Ca'),
#  (0.30607982368428044, '0_K'),
#  (0.0065891250094084934, '1_Ca'),
#  (0.003664613439400279, '1_K'),
#  (0.0011368176618924257, '1_Na')]

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score

start = time.time()
y_train_pred = reg_best.predict(X_train_norm)
end = time.time()
print("time = ", start - end)
print()

mse = mean_squared_error(y_train, y_train_pred)
print('mse: ',mse)
rmse = np.sqrt(mse)
print('rmse: ',rmse)
mae = mean_absolute_error(y_train, y_train_pred)
print('mae: ',mae)

r2_model = r2_score(y_train, y_train_pred)
print('\nR2: ',r2_model)
# Out:
# time =  -2.1907835006713867
#
# mse:  1.551188518432155e-07
# rmse:  0.00039385130676844975
# mae:  0.00023949383587521908
#
# R2:  0.9999991043316648

# %%
start = time.time()
y_test_pred = reg_best.predict(X_test_norm)
end = time.time()
print("time = ", start - end)
print()

mse = mean_squared_error(y_test, y_test_pred)
print('mse: ',mse)
rmse = np.sqrt(mse)
print('rmse: ',rmse)
mae = mean_absolute_error(y_test, y_test_pred)
print('mae: ',mae)

r2_model = r2_score(y_test, y_test_pred)
print('\nR2: ',r2_model)
# Out:
# time =  -0.6608619689941406
#
# mse:  0.0006142203712747215
# rmse:  0.024783469718236015
# mae:  0.016036438494390726
#
# R2:  0.9963946074660788

# %%
mpl.rcParams.update({'font.size': 20})
mpl.rc('xtick', labelsize=18) 
mpl.rc('ytick', labelsize=18) 
mpl.rc('axes', labelsize=22)
fig, axes = plt.subplots(1,3, figsize=[18,5])

for i, ax in enumerate(axes.flat):
    aux_train = y_train[:,i]
    aux_pred = y_train_pred[:,i]
    index = np.argsort(aux_train)
    x = range(len(index))
    ax.plot(x, aux_train[index], 'r-')
    ax.scatter(x, aux_pred[index], alpha=0.1)
    ax.legend(['y_train', 'y_pred'])
    ax.set_xlabel('instances')
    ax.set_ylabel(outputs[i].split('_')[1])
    ax.grid()
plt.tight_layout()

print('\n\n')

fig, axes = plt.subplots(1,3, figsize=[18,5])

for i, ax in enumerate(axes.flat):
    ax.scatter(y_train[:,i], y_train_pred[:,i], alpha=0.5)
    ax.set_xlabel('True '+outputs[i].split('_')[1])
    ax.set_ylabel('Predicted '+outputs[i].split('_')[1])
    ax.grid()
plt.tight_layout()

# %%
mpl.rcParams.update({'font.size': 20})
mpl.rc('xtick', labelsize=18) 
mpl.rc('ytick', labelsize=18) 
mpl.rc('axes', labelsize=22)
fig, axes = plt.subplots(1,3, figsize=[18,5])

for i, ax in enumerate(axes.flat):
    aux_train = y_test[:,i]
    aux_pred = y_test_pred[:,i]
    index = np.argsort(aux_train)
    x = range(len(index))
    ax.plot(x, aux_train[index], 'r-')
    ax.scatter(x, aux_pred[index], alpha=0.1)
    ax.legend(['y_train', 'y_pred'])
    ax.set_xlabel('instances')
    ax.set_ylabel(outputs[i].split('_')[1])
    ax.grid()
plt.tight_layout()

print('\n\n')

fig, axes = plt.subplots(1,3, figsize=[18,5])

for i, ax in enumerate(axes.flat):
    ax.scatter(y_test[:,i], y_test_pred[:,i], alpha=0.5)
    ax.set_xlabel('True '+outputs[i].split('_')[1])
    ax.set_ylabel('Predicted '+outputs[i].split('_')[1])
    ax.grid()
plt.tight_layout()

# %% [markdown]
# ## Run time

# %%
start = time.time()
for i in range(100):  
    reg_best.predict(X_test_norm[0:10000])
end = time.time()
print("time = ", (start - end)/100)
print()
# Out:
# time =  -0.38572722911834717

# %% [markdown]
# ## Model persistence

# %%
final_model = Pipeline([
        ("norm", norm_pipeline),
        ("reg", reg_best)
        ])

print('rmse: ', np.sqrt(mean_squared_error(y_test, final_model.predict(X_test))))
# Out:
# rmse:  0.024783469718236015

# %%
import joblib
from sklearn.metrics import mean_squared_error

#joblib.dump(final_model, "RFmodel.pkl")
final_model_loaded = joblib.load("RFmodel.pkl") 

print('rmse: ', np.sqrt(mean_squared_error(y_test, final_model_loaded.predict(X_test))))
# Out:
# rmse:  0.024783469718236015

# %%
# Add Physics-constrained

y_test_pred = final_model_loaded.predict(X_test)
y_test_pred = (y_test_pred.T*(2*X_test[:, 0]+X_test[:, 1]+X_test[:, 2]) \
                         /(2*y_test_pred[:, 0]+y_test_pred[:, 1]+y_test_pred[:, 2])).T
print('rmse:', np.sqrt(mean_squared_error(y_test, y_test_pred)))
# Out:
# rmse: 0.02403889551932417

# %%
start = time.time()
final_model_loaded = joblib.load("RFmodel.pkl") 
end_load = time.time()
print('Load time = ', end_load - start)
start = time.time()
for i in range(1000):    
    y_pred = final_model_loaded.predict(X_test[0:1])
end = time.time()    
print('Prediction time 1 = ', (end - start)/1000)
start = time.time()
for i in range(1000):    
    y_pred = final_model_loaded.predict(X_test[0:1000])
end = time.time()    
print('Prediction time 1000 = ', (end - start)/1000)
start = time.time()
for i in range(1000):    
    y_pred = final_model_loaded.predict(X_test[0:10000])
end = time.time()    
print('Prediction time 10,000 = ', (end - start)/1000)
# Out:
# Load time =  1.331160306930542
# Prediction time 1 =  0.005604913473129272
# Prediction time 1000 =  0.07090375638008117
# Prediction time 10,000 =  0.38524060416221617

# %% [markdown]
# ## Model persistence Multi-Threading

# %%
from sklearn.ensemble import RandomForestRegressor

# train across 3 folds
reg_best2 = RandomForestRegressor(random_state=42,
                                  bootstrap= False, 
                                  max_depth= 20, 
                                  max_features= 0.6, 
                                  min_samples_leaf= 1, 
                                  min_samples_split= 2, 
                                  n_estimators= 100,
                                  n_jobs=-1)
                           
start = time.time()
reg_best2.fit(X_train_norm, y_train)
print("Run time = ", time.time()-start)
# Out:
# Run time =  0.9025115966796875

# %%
final_model = Pipeline([
        ("norm", norm_pipeline),
        ("reg", reg_best2)
        ])

print('rmse: ', np.sqrt(mean_squared_error(y_test, final_model.predict(X_test))))
# Out:
# rmse:  0.024783469718236015

# %%
import joblib
from sklearn.metrics import mean_squared_error

joblib.dump(final_model, "RFmodel_multithread.pkl")
final_model_loaded = joblib.load("RFmodel_multithread.pkl") 

print('rmse: ', np.sqrt(mean_squared_error(y_test, final_model_loaded.predict(X_test))))
# Out:
# rmse:  0.02478346971823602

# %%
start = time.time()
final_model_loaded = joblib.load("RFmodel_multithread.pkl") 
end_load = time.time()
print('Load time = ', end_load - start)
start = time.time()
for i in range(1000):    
    y_pred = final_model_loaded.predict(X_test[0:1])
end = time.time()    
print('Prediction time 1 = ', (end - start)/1000)
start = time.time()
for i in range(1000):    
    y_pred = final_model_loaded.predict(X_test[0:1000])
end = time.time()    
print('Prediction time 1000 = ', (end - start)/1000)
start = time.time()
for i in range(1000):    
    y_pred = final_model_loaded.predict(X_test[0:10000])
end = time.time()    
print('Prediction time 10,000 = ', (end - start)/1000)
# Out:
# Load time =  0.9496033191680908
# Prediction time 1 =  0.03998212265968323
# Prediction time 1000 =  0.06335119771957397
# Prediction time 10,000 =  0.07587129163742065
