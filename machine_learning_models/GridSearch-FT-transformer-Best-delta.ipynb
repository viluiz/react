# %%
# %reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %%
# Python ≥3.5 is required
import sys
assert sys.version_info >= (3, 5)

# Scikit-Learn ≥1.0.2 is required
import sklearn
assert sklearn.__version__ >= "1.0.2"

# Common imports
import numpy as np
import os
import pandas as pd
import time

# To plot pretty figures
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rcParams.update({'font.size': 20})
mpl.rc('xtick', labelsize=18) 
mpl.rc('ytick', labelsize=18) 
mpl.rc('axes', labelsize=22)

# %% [markdown]
# # Load and process data

# %%
# read data from csv file
trainset = pd.read_csv('../datasets/dataset_MonteCarlo_100.000/trainset.csv')
testset = pd.read_csv('../datasets/dataset_MonteCarlo_100.000/testset.csv')
print(trainset.shape)
print(testset.shape)
# Out:
# (80000, 15)
# (20000, 15)

# %%
trainset['out_Ca_dif'] = trainset['out_Ca']-trainset['0_Ca']
trainset['out_Na_dif'] = trainset['out_Na']-trainset['0_Na']
trainset['out_K_dif'] = trainset['out_K']-trainset['0_K']

# %%
testset['out_Ca_dif'] = testset['out_Ca']-testset['0_Ca']
testset['out_Na_dif'] = testset['out_Na']-testset['0_Na']
testset['out_K_dif'] = testset['out_K']-testset['0_K']

# %%
trainset
# Out:
#            0_Ca      0_Cl      0_Na       0_K      0_N5      1_Ca      1_Cl  \
# 0      0.341575  1.159034  0.012636  0.451710  0.794808  0.347226  0.116634
# 1      0.638607  0.558054  1.231009  0.243433  1.132821  0.038278  0.185744
# 2      0.787981  0.763241  0.349968  0.738449  1.452716  1.117356  0.110285
# 3      0.466115  0.948450  0.942671  1.051085  1.358636  0.470234  0.252135
# 4      0.452663  0.644895  1.360873  0.991130  0.162887  1.361588  1.475943
# ...         ...       ...       ...       ...       ...       ...       ...
# 79995  0.796601  0.398041  1.132371  0.996845  0.094560  1.074895  1.055513
# 79996  0.942419  1.456538  1.164360  0.775981  0.069458  1.024540  1.025283
# 79997  1.095302  0.438446  1.335379  0.365207  0.273701  0.765942  0.880543
# 79998  0.310626  0.661302  0.192742  1.280823  0.931653  0.199012  0.072267
# 79999  0.615264  0.605845  0.029464  0.670703  0.573957  0.756683  0.786792
#
#            1_Na       1_K      1_N5  out_Ca  out_Cl   out_Na   out_K   out_N5  \
# 0      0.755911  0.674340  1.359338  0.3233  1.1590  0.02901  0.4719  0.79480
# 1      0.734268  1.464984  1.489907  0.4584  0.5581  1.24700  0.5882  1.13300
# 2      0.393380  0.282715  1.466671  0.8053  0.7632  0.34980  0.7038  1.45300
# 3      0.914662  1.318543  1.076570  0.4558  0.9484  0.94180  1.0730  1.35900
# 4      0.637112  0.397679  1.414160  0.4939  0.6449  1.34300  0.9266  0.16290
# ...         ...       ...       ...     ...     ...      ...     ...      ...
# 79995  0.777877  0.870241  0.361988  0.8083  0.3980  1.12600  0.9802  0.09456
# 79996  0.144121  1.438743  0.241862  0.9305  1.4570  1.15000  0.8141  0.06946
# 79997  1.152310  1.119219  1.104459  1.0670  0.4384  1.33500  0.4223  0.27370
# 79998  0.870017  0.563615  0.006399  0.3275  0.6613  0.21380  1.2260  0.93170
# 79999  0.335492  1.038286  1.078064  0.6031  0.6058  0.03403  0.6905  0.57400
#
#        out_Ca_dif  out_Na_dif  out_K_dif
# 0       -0.018275    0.016374   0.020190
# 1       -0.180207    0.015991   0.344767
# 2        0.017319   -0.000168  -0.034649
# 3       -0.010315   -0.000871   0.021915
# 4        0.041237   -0.017873  -0.064530
# ...           ...         ...        ...
# 79995    0.011699   -0.006371  -0.016645
# 79996   -0.011919   -0.014360   0.038119
# 79997   -0.028302   -0.000379   0.057093
# 79998    0.016874    0.021058  -0.054823
# 79999   -0.012164    0.004566   0.019797
#
# [80000 rows x 18 columns]

# %%
trainset.hist(figsize=(18, 15));
plt.tight_layout()

# %%
# split x and y
X_train = trainset.iloc[:, [0,2,3,5,7,8]].values 
y_train = trainset.iloc[:, [15, 16, 17]].values
X_test = testset.iloc[:, [0,2,3,5,7,8]].values 
y_test = testset.iloc[:, [15, 16, 17]].values

# Name variables
inputs = [list(trainset)[i] for i in [0,2,3,5,7,8]] 
outputs = [list(trainset)[i] for i in [15, 16, 17]] # do not work for list -> list(trainset)[10, 12, 13]

# %%
from sklearn.model_selection import train_test_split

X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=4)

# %%
print('Inputs: ', inputs)
print('Outputs: ', outputs)
print('X_train instances: ', X_train.shape)
print('X_test instances: ', X_test.shape)
print('X_val instances: ', X_val.shape)
print('y_train instances: ', y_train.shape)
print('y_test instances: ', y_test.shape)
print('y_val instances: ', y_val.shape)
# Out:
# Inputs:  ['0_Ca', '0_Na', '0_K', '1_Ca', '1_Na', '1_K']
# Outputs:  ['out_Ca_dif', 'out_Na_dif', 'out_K_dif']
# X_train instances:  (64000, 6)
# X_test instances:  (20000, 6)
# X_val instances:  (16000, 6)
# y_train instances:  (64000, 3)
# y_test instances:  (20000, 3)
# y_val instances:  (16000, 3)

# %% [markdown]
# ## Normalize data

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import MinMaxScaler, StandardScaler

norm_pipeline = Pipeline([
        ('minmax_scaler', MinMaxScaler((-1,1))),
    ])

X_train_norm = norm_pipeline.fit_transform(X_train)
X_test_norm = norm_pipeline.transform(X_test)
X_val_norm = norm_pipeline.transform(X_val)

# %%
a = norm_pipeline['minmax_scaler']
a.data_max_
# Out:
# array([1.49997587, 1.49999182, 1.49999116, 1.49997541, 1.49999112,
#        1.49998768])

# %%
a.data_min_
# Out:
# array([2.40311919e-05, 4.88878123e-07, 2.50729397e-06, 1.07587663e-06,
#        7.33135675e-06, 1.21962831e-05])

# %% [raw]
# ynorm_pipeline = Pipeline([
#         ('minmax_scaler', MinMaxScaler((-1,1))),
#     ])
#
# y_train_norm = ynorm_pipeline.fit_transform(y_train)
# y_test_norm = ynorm_pipeline.transform(y_test)
# y_val_norm = ynorm_pipeline.transform(y_val)

# %% [markdown]
# # FT-Transformer

# %% [markdown]
# https://github.com/Yura52/rtdl (FT-Transformer)

# %% [markdown]
# https://yura52.github.io/delu/stable/index.html (zero changed to delu)

# %%
# Requirements:
# !pip install rtdl
# !pip install libzero==0.0.4
# Out:
# Requirement already satisfied: rtdl in /home/viluiz/anaconda3/envs/py3ml2-tab/lib/python3.9/site-packages (0.0.13)
# Requirement already satisfied: torch<2,>=1.7 in /home/viluiz/anaconda3/envs/py3ml2-tab/lib/python3.9/site-packages (from rtdl) (1.12.1)
# Requirement already satisfied: numpy<2,>=1.18 in /home/viluiz/anaconda3/envs/py3ml2-tab/lib/python3.9/site-packages (from rtdl) (1.21.2)
# Requirement already satisfied: typing-extensions in /home/viluiz/anaconda3/envs/py3ml2-tab/lib/python3.9/site-packages (from torch<2,>=1.7->rtdl) (4.1.1)
# Requirement already satisfied: libzero==0.0.4 in /home/viluiz/anaconda3/envs/py3ml2-tab/lib/python3.9/site-packages (0.0.4)
# Requirement already satisfied: pynvml<9,>=8.0 in /home/viluiz/anaconda3/envs/py3ml2-tab/lib/python3.9/site-packages (from libzero==0.0.4) (8.0.4)
# Requirement already satisfied: numpy<2,>=1.17 in /home/viluiz/anaconda3/envs/py3ml2-tab/lib/python3.9/site-packages (from libzero==0.0.4) (1.21.2)
# Requirement already satisfied: torch<2,>=1.6 in /home/viluiz/anaconda3/envs/py3ml2-tab/lib/python3.9/site-packages (from libzero==0.0.4) (1.12.1)
# Requirement already satisfied: tqdm<5,>=4.0 in /home/viluiz/anaconda3/envs/py3ml2-tab/lib/python3.9/site-packages (from libzero==0.0.4) (4.64.0)
# Requirement already satisfied: typing-extensions in /home/viluiz/anaconda3/envs/py3ml2-tab/lib/python3.9/site-packages (from torch<2,>=1.6->libzero==0.0.4) (4.1.1)

# %%
import rtdl
import torch
import torch.nn as nn
import torch.nn.functional as F
import zero

# %%
print('torch.cuda.is_available:\t',torch.cuda.is_available())
print('torch.cuda.device_count:\t',torch.cuda.device_count())
print('torch.cuda.current_device:\t',torch.cuda.current_device())
print('torch.cuda.device:\t\t',torch.cuda.device(0))
print('torch.cuda.get_device_name:\t',torch.cuda.get_device_name(0))
# Out:
# torch.cuda.is_available:	 True
# torch.cuda.device_count:	 1
# torch.cuda.current_device:	 0
# torch.cuda.device:		 <torch.cuda.device object at 0x7fec53447670>
# torch.cuda.get_device_name:	 Quadro RTX 4000

# %%
#device = torch.device('cpu')
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
# Docs: https://yura52.github.io/zero/0.0.4/reference/api/zero.improve_reproducibility.html
zero.improve_reproducibility(seed=123456)
# Out:
# 123456

# %%
X_train_norm = torch.tensor(X_train_norm.astype('float32')).to(device)
X_test_norm = torch.tensor(X_test_norm.astype('float32')).to(device)
X_val_norm = torch.tensor(X_val_norm.astype('float32')).to(device)
y_train = torch.tensor(y_train.astype('float32')).to(device)
y_test = torch.tensor(y_test.astype('float32')).to(device)
y_val = torch.tensor(y_val.astype('float32')).to(device)

# %%
# Best parameters from Gridsearch_FT-transformer.ipynb
model = rtdl.FTTransformer.make_baseline(
            n_num_features=X_train.shape[1],
            cat_cardinalities=None,
            last_layer_query_idx=[-1], 
            d_token=192, #192,
            n_blocks=3, #3,
            ffn_d_hidden=256,
            attention_dropout=0.1, #0.2,
            ffn_dropout=0.2, #0.1,
            residual_dropout=0.0,
            d_out=y_train.shape[1])
model.to(device)

optimizer = model.make_default_optimizer()
loss_fn = F.mse_loss

#def apply_model(x_num, x_cat=None):
#        return model(x_num, x_cat)
    
@torch.no_grad()
def evaluate(X,y):
    
    model.eval()
    prediction = []
    for batch in zero.iter_batches(X, 1024):
        #batch.to(device)
        prediction.append(model(batch,None))
    prediction = torch.cat(prediction).squeeze(1).cpu().numpy()
    target = y.cpu().numpy()

    score = np.sqrt(sklearn.metrics.mean_squared_error(target, prediction))
    
    return score

# %%
# Create a dataloader for batches of indices
# Docs: https://yura52.github.io/zero/reference/api/zero.data.IndexLoader.html
batch_size = 256
train_loader = zero.data.IndexLoader(len(X_train_norm), batch_size)

# Create a progress tracker for early stopping
# Docs: https://yura52.github.io/zero/reference/api/zero.ProgressTracker.html
progress = zero.ProgressTracker(patience=500)

# %%
n_epochs = 500
checkpoint_path = 'checkpoint.pt' 
#report_frequency = len(X_train_norm) // batch_size // 3

for epoch in range(1, n_epochs + 1):
    start = time.time()
    model.train()
    for iteration, batch_idx in enumerate(train_loader):
        
        x_batch = X_train_norm[batch_idx]
        y_batch = y_train[batch_idx]
        loss = loss_fn(model(x_batch,None).squeeze(1), y_batch)
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        #if iteration % report_frequency == 0:
        #    print(f'(epoch) {epoch} (batch) {iteration} (loss) {loss.item():.4f}')
    
    val_score = evaluate(X_val_norm, y_val)
    test_score = evaluate(X_test_norm, y_test)
    print(f'Epoch {epoch:03d} | Validation score: {val_score:.4f} | Test score: {test_score:.4f} | {time.time()-start:.1f}s', end='')
    progress.update(-val_score)
    if progress.success:
        print(' <<< BEST VALIDATION EPOCH', end='')
        torch.save({'epoch': epoch,
                    'model_state_dict': model.state_dict(),
                    'optimizer_state_dict': optimizer.state_dict(),
                    'loss': loss,},
                    checkpoint_path)
    print()
    if progress.fail or epoch == n_epochs:
        checkpoint = torch.load(checkpoint_path)
        model.load_state_dict(checkpoint['model_state_dict'])
        optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
        epoch = checkpoint['epoch']
        loss = checkpoint['loss']
        val_score = evaluate(X_val_norm, y_val)
        test_score = evaluate(X_test_norm, y_test)
        print('Checkpoint recovered:')
        print(f'Epoch {epoch:03d} | Validation score: {val_score:.4f} | Test score: {test_score:.4f} | {time.time()-start:.1f}s', end='')
        break
# Out:
# Epoch 001 | Validation score: 0.0279 | Test score: 0.0277 | 4.2s <<< BEST VALIDATION EPOCH
# Epoch 002 | Validation score: 0.0201 | Test score: 0.0203 | 4.1s <<< BEST VALIDATION EPOCH
# Epoch 003 | Validation score: 0.0138 | Test score: 0.0143 | 4.2s <<< BEST VALIDATION EPOCH
# Epoch 004 | Validation score: 0.0133 | Test score: 0.0139 | 4.4s <<< BEST VALIDATION EPOCH
# Epoch 005 | Validation score: 0.0126 | Test score: 0.0130 | 4.3s <<< BEST VALIDATION EPOCH
# Epoch 006 | Validation score: 0.0148 | Test score: 0.0152 | 4.3s
# Epoch 007 | Validation score: 0.0095 | Test score: 0.0098 | 4.3s <<< BEST VALIDATION EPOCH
# Epoch 008 | Validation score: 0.0090 | Test score: 0.0095 | 4.3s <<< BEST VALIDATION EPOCH
# Epoch 009 | Validation score: 0.0084 | Test score: 0.0088 | 4.2s <<< BEST VALIDATION EPOCH
# Epoch 010 | Validation score: 0.0074 | Test score: 0.0078 | 4.2s <<< BEST VALIDATION EPOCH
# Epoch 011 | Validation score: 0.0094 | Test score: 0.0095 | 4.3s
# Epoch 012 | Validation score: 0.0078 | Test score: 0.0082 | 4.4s
# Epoch 013 | Validation score: 0.0119 | Test score: 0.0120 | 4.4s
# Epoch 014 | Validation score: 0.0123 | Test score: 0.0122 | 4.5s
# Epoch 015 | Validation score: 0.0122 | Test score: 0.0122 | 4.3s
# Epoch 016 | Validation score: 0.0116 | Test score: 0.0117 | 4.6s
# Epoch 017 | Validation score: 0.0172 | Test score: 0.0170 | 4.2s
# Epoch 018 | Validation score: 0.0101 | Test score: 0.0102 | 4.1s
# Epoch 019 | Validation score: 0.0073 | Test score: 0.0075 | 4.4s <<< BEST VALIDATION EPOCH
# Epoch 020 | Validation score: 0.0135 | Test score: 0.0137 | 4.3s
# Epoch 021 | Validation score: 0.0065 | Test score: 0.0065 | 4.3s <<< BEST VALIDATION EPOCH
# Epoch 022 | Validation score: 0.0058 | Test score: 0.0060 | 4.2s <<< BEST VALIDATION EPOCH
# Epoch 023 | Validation score: 0.0074 | Test score: 0.0076 | 4.3s
# Epoch 024 | Validation score: 0.0067 | Test score: 0.0069 | 4.2s
# Epoch 025 | Validation score: 0.0058 | Test score: 0.0062 | 4.3s
# Epoch 026 | Validation score: 0.0161 | Test score: 0.0159 | 4.2s
# Epoch 027 | Validation score: 0.0077 | Test score: 0.0081 | 4.2s
# Epoch 028 | Validation score: 0.0088 | Test score: 0.0088 | 4.2s
# Epoch 029 | Validation score: 0.0065 | Test score: 0.0068 | 4.2s
# Epoch 030 | Validation score: 0.0087 | Test score: 0.0089 | 4.2s
# Epoch 031 | Validation score: 0.0092 | Test score: 0.0093 | 4.4s
# Epoch 032 | Validation score: 0.0085 | Test score: 0.0086 | 4.3s
# Epoch 033 | Validation score: 0.0061 | Test score: 0.0061 | 4.4s
# Epoch 034 | Validation score: 0.0057 | Test score: 0.0059 | 4.3s <<< BEST VALIDATION EPOCH
# Epoch 035 | Validation score: 0.0058 | Test score: 0.0061 | 4.3s
# Epoch 036 | Validation score: 0.0047 | Test score: 0.0050 | 4.3s <<< BEST VALIDATION EPOCH
# Epoch 037 | Validation score: 0.0062 | Test score: 0.0063 | 4.2s
# Epoch 038 | Validation score: 0.0063 | Test score: 0.0066 | 4.2s
# Epoch 039 | Validation score: 0.0061 | Test score: 0.0063 | 4.2s
# Epoch 040 | Validation score: 0.0072 | Test score: 0.0071 | 4.2s
# Epoch 041 | Validation score: 0.0059 | Test score: 0.0061 | 4.1s
# Epoch 042 | Validation score: 0.0117 | Test score: 0.0117 | 4.2s
# Epoch 043 | Validation score: 0.0067 | Test score: 0.0068 | 4.2s
# Epoch 044 | Validation score: 0.0052 | Test score: 0.0054 | 4.2s
# Epoch 045 | Validation score: 0.0146 | Test score: 0.0147 | 4.2s
# Epoch 046 | Validation score: 0.0047 | Test score: 0.0049 | 4.3s <<< BEST VALIDATION EPOCH
# Epoch 047 | Validation score: 0.0050 | Test score: 0.0052 | 4.3s
# Epoch 048 | Validation score: 0.0059 | Test score: 0.0060 | 4.2s
# Epoch 049 | Validation score: 0.0056 | Test score: 0.0058 | 4.2s
# Epoch 050 | Validation score: 0.0052 | Test score: 0.0054 | 4.2s
# Epoch 051 | Validation score: 0.0056 | Test score: 0.0058 | 4.4s
# Epoch 052 | Validation score: 0.0056 | Test score: 0.0059 | 4.2s
# Epoch 053 | Validation score: 0.0051 | Test score: 0.0052 | 4.2s
# Epoch 054 | Validation score: 0.0103 | Test score: 0.0104 | 4.4s
# Epoch 055 | Validation score: 0.0043 | Test score: 0.0045 | 4.3s <<< BEST VALIDATION EPOCH
# Epoch 056 | Validation score: 0.0103 | Test score: 0.0102 | 4.2s
# Epoch 057 | Validation score: 0.0073 | Test score: 0.0075 | 4.1s
# Epoch 058 | Validation score: 0.0051 | Test score: 0.0053 | 3.8s
# Epoch 059 | Validation score: 0.0059 | Test score: 0.0058 | 4.1s
# Epoch 100 | Validation score: 0.0069 | Test score: 0.0068 | 4.4s
# Epoch 101 | Validation score: 0.0100 | Test score: 0.0098 | 4.3s
# Epoch 102 | Validation score: 0.0101 | Test score: 0.0099 | 4.5s
# Epoch 103 | Validation score: 0.0061 | Test score: 0.0059 | 4.5s
# Epoch 104 | Validation score: 0.0099 | Test score: 0.0098 | 4.4s
# Epoch 105 | Validation score: 0.0105 | Test score: 0.0104 | 4.3s
# Epoch 106 | Validation score: 0.0044 | Test score: 0.0044 | 4.3s
# Epoch 107 | Validation score: 0.0059 | Test score: 0.0055 | 4.3s
# Epoch 108 | Validation score: 0.0048 | Test score: 0.0048 | 4.4s
# Epoch 109 | Validation score: 0.0067 | Test score: 0.0068 | 4.2s
# Epoch 110 | Validation score: 0.0049 | Test score: 0.0050 | 4.4s
# Epoch 111 | Validation score: 0.0093 | Test score: 0.0092 | 4.8s
# Epoch 112 | Validation score: 0.0068 | Test score: 0.0066 | 4.3s
# Epoch 113 | Validation score: 0.0067 | Test score: 0.0067 | 4.3s
# Epoch 114 | Validation score: 0.0091 | Test score: 0.0089 | 4.4s
# Epoch 115 | Validation score: 0.0054 | Test score: 0.0053 | 4.3s
# Epoch 116 | Validation score: 0.0051 | Test score: 0.0050 | 4.5s
# Epoch 117 | Validation score: 0.0058 | Test score: 0.0057 | 4.5s
# Epoch 118 | Validation score: 0.0060 | Test score: 0.0060 | 4.5s
# Epoch 119 | Validation score: 0.0064 | Test score: 0.0063 | 4.3s
# Epoch 120 | Validation score: 0.0047 | Test score: 0.0046 | 4.4s
# Epoch 121 | Validation score: 0.0043 | Test score: 0.0044 | 4.4s <<< BEST VALIDATION EPOCH
# Epoch 122 | Validation score: 0.0045 | Test score: 0.0044 | 4.3s
# Epoch 123 | Validation score: 0.0039 | Test score: 0.0039 | 4.4s <<< BEST VALIDATION EPOCH
# Epoch 124 | Validation score: 0.0104 | Test score: 0.0103 | 4.5s
# Epoch 125 | Validation score: 0.0057 | Test score: 0.0055 | 4.8s
# Epoch 126 | Validation score: 0.0070 | Test score: 0.0068 | 4.4s
# Epoch 127 | Validation score: 0.0050 | Test score: 0.0047 | 4.3s
# Epoch 128 | Validation score: 0.0079 | Test score: 0.0076 | 4.4s
# Epoch 129 | Validation score: 0.0061 | Test score: 0.0058 | 4.5s
# Epoch 130 | Validation score: 0.0046 | Test score: 0.0046 | 4.7s
# Epoch 131 | Validation score: 0.0091 | Test score: 0.0090 | 4.9s
# Epoch 132 | Validation score: 0.0045 | Test score: 0.0043 | 4.8s
# Epoch 133 | Validation score: 0.0050 | Test score: 0.0048 | 4.8s
# Epoch 134 | Validation score: 0.0040 | Test score: 0.0038 | 4.8s
# Epoch 135 | Validation score: 0.0039 | Test score: 0.0039 | 4.8s
# Epoch 136 | Validation score: 0.0067 | Test score: 0.0062 | 4.4s
# Epoch 137 | Validation score: 0.0030 | Test score: 0.0035 | 4.8s <<< BEST VALIDATION EPOCH
# Epoch 138 | Validation score: 0.0077 | Test score: 0.0075 | 4.5s
# Epoch 261 | Validation score: 0.0059 | Test score: 0.0058 | 4.6s
# Epoch 262 | Validation score: 0.0057 | Test score: 0.0054 | 4.5s
# Epoch 263 | Validation score: 0.0039 | Test score: 0.0040 | 4.3s
# Epoch 264 | Validation score: 0.0087 | Test score: 0.0089 | 4.7s
# Epoch 265 | Validation score: 0.0036 | Test score: 0.0037 | 5.0s
# Epoch 266 | Validation score: 0.0034 | Test score: 0.0034 | 5.0s
# Epoch 267 | Validation score: 0.0052 | Test score: 0.0047 | 5.0s
# Epoch 268 | Validation score: 0.0043 | Test score: 0.0041 | 5.0s
# Epoch 269 | Validation score: 0.0038 | Test score: 0.0040 | 4.9s
# Epoch 270 | Validation score: 0.0041 | Test score: 0.0042 | 5.0s
# Epoch 271 | Validation score: 0.0034 | Test score: 0.0036 | 5.0s
# Epoch 272 | Validation score: 0.0049 | Test score: 0.0048 | 5.0s
# Epoch 273 | Validation score: 0.0035 | Test score: 0.0038 | 4.9s
# Epoch 274 | Validation score: 0.0062 | Test score: 0.0061 | 4.5s
# Epoch 275 | Validation score: 0.0037 | Test score: 0.0042 | 4.5s
# Epoch 276 | Validation score: 0.0032 | Test score: 0.0037 | 4.4s
# Epoch 277 | Validation score: 0.0047 | Test score: 0.0046 | 4.4s
# Epoch 278 | Validation score: 0.0076 | Test score: 0.0074 | 4.4s
# Epoch 279 | Validation score: 0.0076 | Test score: 0.0066 | 4.4s
# Epoch 280 | Validation score: 0.0032 | Test score: 0.0035 | 4.5s
# Epoch 281 | Validation score: 0.0056 | Test score: 0.0053 | 4.5s
# Epoch 282 | Validation score: 0.0040 | Test score: 0.0042 | 4.4s
# Epoch 283 | Validation score: 0.0038 | Test score: 0.0035 | 4.3s
# Epoch 284 | Validation score: 0.0056 | Test score: 0.0055 | 4.3s
# Epoch 285 | Validation score: 0.0040 | Test score: 0.0039 | 4.4s
# Epoch 286 | Validation score: 0.0071 | Test score: 0.0071 | 4.6s
# Epoch 287 | Validation score: 0.0034 | Test score: 0.0034 | 4.6s
# Epoch 288 | Validation score: 0.0036 | Test score: 0.0039 | 4.9s
# Epoch 289 | Validation score: 0.0087 | Test score: 0.0084 | 4.7s
# Epoch 290 | Validation score: 0.0055 | Test score: 0.0052 | 4.5s
# Epoch 291 | Validation score: 0.0044 | Test score: 0.0045 | 4.7s
# Epoch 292 | Validation score: 0.0042 | Test score: 0.0045 | 4.4s
# Epoch 293 | Validation score: 0.0035 | Test score: 0.0036 | 4.5s
# Epoch 294 | Validation score: 0.0038 | Test score: 0.0039 | 4.4s
# Epoch 295 | Validation score: 0.0082 | Test score: 0.0084 | 4.6s
# Epoch 296 | Validation score: 0.0050 | Test score: 0.0051 | 4.9s
# Epoch 297 | Validation score: 0.0043 | Test score: 0.0043 | 4.9s
# Epoch 298 | Validation score: 0.0038 | Test score: 0.0040 | 4.5s
# Epoch 299 | Validation score: 0.0047 | Test score: 0.0047 | 4.3s
# Epoch 300 | Validation score: 0.0038 | Test score: 0.0036 | 4.1s
# Epoch 382 | Validation score: 0.0034 | Test score: 0.0033 | 4.2s
# Epoch 383 | Validation score: 0.0083 | Test score: 0.0082 | 4.2s
# Epoch 384 | Validation score: 0.0045 | Test score: 0.0046 | 4.1s
# Epoch 385 | Validation score: 0.0034 | Test score: 0.0031 | 4.2s
# Epoch 386 | Validation score: 0.0035 | Test score: 0.0035 | 4.2s
# Epoch 387 | Validation score: 0.0037 | Test score: 0.0037 | 4.2s
# Epoch 388 | Validation score: 0.0090 | Test score: 0.0090 | 4.2s
# Epoch 389 | Validation score: 0.0039 | Test score: 0.0040 | 4.2s
# Epoch 390 | Validation score: 0.0035 | Test score: 0.0035 | 4.2s
# Epoch 391 | Validation score: 0.0044 | Test score: 0.0043 | 4.2s
# Epoch 392 | Validation score: 0.0037 | Test score: 0.0036 | 4.2s
# Epoch 393 | Validation score: 0.0043 | Test score: 0.0042 | 4.2s
# Epoch 394 | Validation score: 0.0051 | Test score: 0.0050 | 4.2s
# Epoch 395 | Validation score: 0.0037 | Test score: 0.0036 | 4.1s
# Epoch 396 | Validation score: 0.0040 | Test score: 0.0040 | 4.2s
# Epoch 397 | Validation score: 0.0036 | Test score: 0.0034 | 4.2s
# Epoch 398 | Validation score: 0.0034 | Test score: 0.0031 | 4.2s
# Epoch 399 | Validation score: 0.0040 | Test score: 0.0043 | 4.2s
# Epoch 400 | Validation score: 0.0055 | Test score: 0.0053 | 4.2s
# Epoch 401 | Validation score: 0.0044 | Test score: 0.0043 | 4.2s
# Epoch 402 | Validation score: 0.0050 | Test score: 0.0050 | 4.2s
# Epoch 403 | Validation score: 0.0081 | Test score: 0.0080 | 4.2s
# Epoch 404 | Validation score: 0.0041 | Test score: 0.0037 | 4.1s
# Epoch 405 | Validation score: 0.0036 | Test score: 0.0035 | 4.2s
# Epoch 406 | Validation score: 0.0036 | Test score: 0.0033 | 4.2s
# Epoch 407 | Validation score: 0.0040 | Test score: 0.0039 | 4.2s
# Epoch 408 | Validation score: 0.0039 | Test score: 0.0038 | 4.2s
# Epoch 409 | Validation score: 0.0047 | Test score: 0.0045 | 4.2s
# Epoch 410 | Validation score: 0.0037 | Test score: 0.0038 | 4.2s
# Epoch 411 | Validation score: 0.0040 | Test score: 0.0037 | 4.3s
# Epoch 412 | Validation score: 0.0058 | Test score: 0.0052 | 4.2s
# Epoch 413 | Validation score: 0.0037 | Test score: 0.0035 | 4.2s
# Epoch 414 | Validation score: 0.0037 | Test score: 0.0034 | 4.2s
# Epoch 415 | Validation score: 0.0045 | Test score: 0.0046 | 4.2s
# Epoch 416 | Validation score: 0.0052 | Test score: 0.0049 | 4.2s
# Epoch 417 | Validation score: 0.0043 | Test score: 0.0044 | 4.5s
# Epoch 418 | Validation score: 0.0047 | Test score: 0.0044 | 4.5s
# Epoch 419 | Validation score: 0.0071 | Test score: 0.0072 | 4.4s
# Epoch 420 | Validation score: 0.0049 | Test score: 0.0048 | 4.3s
# Epoch 421 | Validation score: 0.0043 | Test score: 0.0040 | 4.2s
# Epoch 422 | Validation score: 0.0036 | Test score: 0.0033 | 4.2s
# Epoch 423 | Validation score: 0.0052 | Test score: 0.0045 | 4.2s
# Epoch 424 | Validation score: 0.0047 | Test score: 0.0044 | 4.2s
# Epoch 425 | Validation score: 0.0039 | Test score: 0.0036 | 4.4s
# Epoch 426 | Validation score: 0.0084 | Test score: 0.0083 | 4.3s
# Epoch 427 | Validation score: 0.0043 | Test score: 0.0038 | 4.4s
# Epoch 428 | Validation score: 0.0075 | Test score: 0.0076 | 4.2s
# Epoch 429 | Validation score: 0.0043 | Test score: 0.0042 | 4.4s
# Epoch 430 | Validation score: 0.0047 | Test score: 0.0047 | 4.0s
# Epoch 431 | Validation score: 0.0065 | Test score: 0.0062 | 4.2s
# Epoch 432 | Validation score: 0.0050 | Test score: 0.0051 | 4.9s
# Epoch 433 | Validation score: 0.0042 | Test score: 0.0038 | 4.9s
# Epoch 434 | Validation score: 0.0049 | Test score: 0.0047 | 4.8s
# Epoch 435 | Validation score: 0.0041 | Test score: 0.0039 | 4.5s
# Epoch 436 | Validation score: 0.0099 | Test score: 0.0099 | 4.4s
# Epoch 437 | Validation score: 0.0041 | Test score: 0.0041 | 4.5s
# Epoch 438 | Validation score: 0.0044 | Test score: 0.0041 | 4.7s
# Epoch 439 | Validation score: 0.0052 | Test score: 0.0044 | 4.4s
# Epoch 440 | Validation score: 0.0047 | Test score: 0.0047 | 4.3s
# Epoch 441 | Validation score: 0.0069 | Test score: 0.0070 | 4.2s
# Epoch 442 | Validation score: 0.0042 | Test score: 0.0041 | 4.3s
# Epoch 443 | Validation score: 0.0035 | Test score: 0.0035 | 4.1s
# Epoch 444 | Validation score: 0.0037 | Test score: 0.0038 | 4.2s
# Epoch 445 | Validation score: 0.0035 | Test score: 0.0034 | 4.2s
# Epoch 446 | Validation score: 0.0038 | Test score: 0.0036 | 4.0s
# Epoch 447 | Validation score: 0.0068 | Test score: 0.0066 | 4.2s
# Epoch 448 | Validation score: 0.0046 | Test score: 0.0041 | 4.2s
# Epoch 449 | Validation score: 0.0084 | Test score: 0.0084 | 4.3s
# Epoch 450 | Validation score: 0.0053 | Test score: 0.0053 | 4.2s
# Epoch 451 | Validation score: 0.0041 | Test score: 0.0040 | 4.3s
# Epoch 452 | Validation score: 0.0046 | Test score: 0.0045 | 4.3s
# Epoch 453 | Validation score: 0.0049 | Test score: 0.0050 | 4.2s
# Epoch 454 | Validation score: 0.0059 | Test score: 0.0056 | 4.2s
# Epoch 455 | Validation score: 0.0039 | Test score: 0.0038 | 4.2s
# Epoch 456 | Validation score: 0.0039 | Test score: 0.0036 | 4.2s
# Epoch 457 | Validation score: 0.0054 | Test score: 0.0053 | 4.1s
# Epoch 458 | Validation score: 0.0037 | Test score: 0.0033 | 4.2s
# Epoch 459 | Validation score: 0.0038 | Test score: 0.0036 | 4.1s
# Epoch 460 | Validation score: 0.0054 | Test score: 0.0051 | 4.2s
# Epoch 461 | Validation score: 0.0043 | Test score: 0.0039 | 4.2s
# Epoch 462 | Validation score: 0.0039 | Test score: 0.0037 | 4.3s
# Epoch 463 | Validation score: 0.0043 | Test score: 0.0042 | 4.3s
# Epoch 464 | Validation score: 0.0038 | Test score: 0.0036 | 4.2s
# Epoch 465 | Validation score: 0.0053 | Test score: 0.0054 | 4.1s
# Epoch 466 | Validation score: 0.0063 | Test score: 0.0059 | 4.2s
# Epoch 467 | Validation score: 0.0039 | Test score: 0.0040 | 4.1s
# Epoch 468 | Validation score: 0.0044 | Test score: 0.0043 | 4.2s
# Epoch 469 | Validation score: 0.0097 | Test score: 0.0096 | 4.2s
# Epoch 470 | Validation score: 0.0055 | Test score: 0.0054 | 4.1s
# Epoch 471 | Validation score: 0.0039 | Test score: 0.0040 | 4.1s
# Epoch 472 | Validation score: 0.0038 | Test score: 0.0038 | 4.2s
# Epoch 473 | Validation score: 0.0069 | Test score: 0.0068 | 4.2s
# Epoch 474 | Validation score: 0.0050 | Test score: 0.0048 | 4.1s
# Epoch 475 | Validation score: 0.0039 | Test score: 0.0038 | 4.2s
# Epoch 476 | Validation score: 0.0052 | Test score: 0.0052 | 4.2s
# Epoch 477 | Validation score: 0.0053 | Test score: 0.0053 | 4.2s
# Epoch 478 | Validation score: 0.0038 | Test score: 0.0036 | 4.1s
# Epoch 479 | Validation score: 0.0041 | Test score: 0.0039 | 4.2s
# Epoch 480 | Validation score: 0.0039 | Test score: 0.0037 | 4.2s
# Epoch 481 | Validation score: 0.0039 | Test score: 0.0037 | 4.2s
# Epoch 482 | Validation score: 0.0037 | Test score: 0.0034 | 4.1s
# Epoch 483 | Validation score: 0.0039 | Test score: 0.0035 | 4.3s
# Epoch 484 | Validation score: 0.0080 | Test score: 0.0080 | 4.3s
# Epoch 485 | Validation score: 0.0042 | Test score: 0.0038 | 4.3s
# Epoch 486 | Validation score: 0.0047 | Test score: 0.0043 | 4.3s
# Epoch 487 | Validation score: 0.0039 | Test score: 0.0036 | 4.3s
# Epoch 488 | Validation score: 0.0039 | Test score: 0.0036 | 4.2s
# Epoch 489 | Validation score: 0.0040 | Test score: 0.0039 | 4.2s
# Epoch 490 | Validation score: 0.0042 | Test score: 0.0038 | 4.3s
# Epoch 491 | Validation score: 0.0038 | Test score: 0.0038 | 4.2s
# Epoch 492 | Validation score: 0.0048 | Test score: 0.0048 | 4.2s
# Epoch 493 | Validation score: 0.0074 | Test score: 0.0073 | 4.2s
# Epoch 494 | Validation score: 0.0065 | Test score: 0.0064 | 4.1s
# Epoch 495 | Validation score: 0.0042 | Test score: 0.0038 | 4.3s
# Epoch 496 | Validation score: 0.0038 | Test score: 0.0036 | 3.9s
# Epoch 497 | Validation score: 0.0038 | Test score: 0.0036 | 4.3s
# Epoch 498 | Validation score: 0.0042 | Test score: 0.0041 | 4.3s
# Epoch 499 | Validation score: 0.0048 | Test score: 0.0048 | 4.3s
# Epoch 500 | Validation score: 0.0038 | Test score: 0.0035 | 4.2s
# Checkpoint recovered:
# Epoch 137 | Validation score: 0.0030 | Test score: 0.0035 | 4.4s

# %%
device = torch.device('cpu')
model.to(device)
model.eval()
X_train_norm =  X_train_norm.to(device)
X_test_norm = X_test_norm.to(device)
y_train = y_train.to(device)
y_test = y_test.to(device)

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score

start = time.time()
y_train_pred = model(X_train_norm,None).detach().numpy()
end = time.time()
print("time = ", start - end)
print()

mse = mean_squared_error(y_train, y_train_pred)
print('mse: ',mse)
rmse = np.sqrt(mse)
print('rmse: ',rmse)
mae = mean_absolute_error(y_train, y_train_pred)
print('mae: ',mae)

r2_model = r2_score(y_train, y_train_pred)
print('\nR2: ',r2_model)
# Out:
# time =  -4.3905370235443115
#
# mse:  6.4155756e-06
# rmse:  0.0025328987
# mae:  0.0011257777
#
# R2:  0.9952154497190584

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

start = time.time()
y_test_pred = model(X_test_norm,None).detach().numpy()
end = time.time()
print("time = ", start - end)
print()

mse = mean_squared_error(y_test, y_test_pred)
print('mse: ',mse)
rmse = np.sqrt(mse)
print('rmse: ',rmse)
mae = mean_absolute_error(y_test, y_test_pred)
print('mae: ',mae)

r2_model = r2_score(y_test, y_test_pred)
print('\nR2: ',r2_model)
# Out:
# time =  -0.8270680904388428
#
# mse:  1.2540239e-05
# rmse:  0.00354122
# mae:  0.0011613719
#
# R2:  0.9938058576284742

# %%
mpl.rcParams.update({'font.size': 20})
mpl.rc('xtick', labelsize=18) 
mpl.rc('ytick', labelsize=18) 
mpl.rc('axes', labelsize=22)
fig, axes = plt.subplots(1,3, figsize=[18,5])

for i, ax in enumerate(axes.flat):
    aux_train = y_train[:,i]
    aux_pred = y_train_pred[:,i]
    index = np.argsort(aux_train)
    x = range(len(index))
    ax.plot(x, aux_train[index], 'r-')
    ax.scatter(x, aux_pred[index], alpha=0.1)
    ax.legend(['y_train', 'y_pred'])
    ax.set_xlabel('instances')
    ax.set_ylabel(outputs[i].split('_')[1])
    ax.grid()
plt.tight_layout()

print('\n\n')

fig, axes = plt.subplots(1,3, figsize=[18,5])

for i, ax in enumerate(axes.flat):
    ax.scatter(y_train[:,i], y_train_pred[:,i], alpha=0.5)
    ax.set_xlabel('True '+outputs[i].split('_')[1])
    ax.set_ylabel('Predicted '+outputs[i].split('_')[1])
    ax.grid()
plt.tight_layout()

# %%
mpl.rcParams.update({'font.size': 20})
mpl.rc('xtick', labelsize=18) 
mpl.rc('ytick', labelsize=18) 
mpl.rc('axes', labelsize=22)
fig, axes = plt.subplots(1,3, figsize=[18,5])

for i, ax in enumerate(axes.flat):
    aux_train = y_test[:,i]
    aux_pred = y_test_pred[:,i]
    index = np.argsort(aux_train)
    x = range(len(index))
    ax.plot(x, aux_train[index], 'r-')
    ax.scatter(x, aux_pred[index], alpha=0.1)
    ax.legend(['y_train', 'y_pred'])
    ax.set_xlabel('instances')
    ax.set_ylabel(outputs[i].split('_')[1])
    ax.grid()
plt.tight_layout()

print('\n\n')

fig, axes = plt.subplots(1,3, figsize=[18,5])

for i, ax in enumerate(axes.flat):
    ax.scatter(y_test[:,i], y_test_pred[:,i], alpha=0.5)
    ax.set_xlabel('True '+outputs[i].split('_')[1])
    ax.set_ylabel('Predicted '+outputs[i].split('_')[1])
    ax.grid()
plt.tight_layout()
